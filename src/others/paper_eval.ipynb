# %%
## 简单的 exp to be ran

## 复杂的 idea to be implemented
# todo synth预训练 + nominal微调 + edge测试
# todo 在real进行测试
# todo 不早停 使用全部train dataset

# %%
# from ultralytics import YOLO

# path_model = 'cfg/ultralytics/models/yolov8n-p2/yolov8n-p2_afpn.yaml'
# model = YOLO(path_model)
# results = model.train(
#     data='coco128.yaml',
#     epochs=1,
#     project="test",
#     plots=False)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.rcParams['text.usetex'] = False

# 获取结果文件
path = 'results/tables/metrics'
all_csv = os.listdir(path)
all_csv = [file for file in all_csv if file.endswith('csv')]

# 控制分辨率
use1280 = True
if use1280: 
    all_csv = [file for file in all_csv 
               if (file.find('1280')!=-1) | (file.find('baseline')!=-1) | (file.find('metrics_base_yolov8n.csv')!=-1)]
    name_base_model = 'base_yolov8n_1280'
else:
    name_base_model = 'base_yolov8n'

def get_model_name(file):
    # 从文件名截取模型名称
    return file.split('metrics_')[1].split('.csv')[0]

# 使用map@5095或者map@.5
use_5095 = True

# 截取map@5095或者map@.5
map = []
for file in all_csv:
    df = pd.read_csv(os.path.join(path, file))
    if use_5095:
        _map = df.iloc[0:1, :].copy()
    else:
        _map = df.iloc[1:2, :].copy()
    _map['metrics'] = get_model_name(file)
    map.append(_map)

# 数据重构
map = pd.concat(map, axis=0).sort_values(by='test_real')
map.set_index('metrics', inplace=True)

def highlight_base_model_row(s):
    # 高亮name_base_model所在行
    return ['background-color: yellow' if s.name == name_base_model else '' for _ in s]

def highlight_cells(cell, reference_cell):
    # 如果cell的值大于reference_cell则高亮cell
    if cell > reference_cell:
        return 'background-color: red'
    return ''

def highlight_better(row):
    # 对row整行 某个cell大于reference_row的对应cell 则高亮
    reference_row = df.loc[name_base_model]
    return [highlight_cells(cell, reference_cell) for cell, reference_cell in zip(row, reference_row)]

# 应用这个样式到DataFrame
print('map@5095') if use_5095 else print('map@.5')
map.style.bar(
    align='left'
    ).apply(highlight_base_model_row, axis=1
    ).format("{:.3f}")
# Out:
# map@5095
# <style type="text/css">
# #T_57b04_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.7%, transparent 12.7%);
# }
# #T_57b04_row0_col1, #T_57b04_row0_col3, #T_57b04_row6_col2, #T_57b04_row7_col0 {
#   width: 10em;
# }
# #T_57b04_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.5%, transparent 4.5%);
# }
# #T_57b04_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.6%, transparent 7.6%);
# }
# #T_57b04_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.9%, transparent 5.9%);
# }
# #T_57b04_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.8%, transparent 12.8%);
# }
# #T_57b04_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.7%, transparent 5.7%);
# }
# #T_57b04_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.0%, transparent 32.0%);
# }
# #T_57b04_row2_col1, #T_57b04_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.7%, transparent 11.7%);
# }
# #T_57b04_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.3%, transparent 0.3%);
# }
# #T_57b04_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.9%, transparent 8.9%);
# }
# #T_57b04_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.2%, transparent 14.2%);
# }
# #T_57b04_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.2%, transparent 29.2%);
# }
# #T_57b04_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.3%, transparent 14.3%);
# }
# #T_57b04_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 23.9%, transparent 23.9%);
# }
# #T_57b04_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.6%, transparent 17.6%);
# }
# #T_57b04_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.0%, transparent 25.0%);
# }
# #T_57b04_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.2%, transparent 18.2%);
# }
# #T_57b04_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.5%, transparent 30.5%);
# }
# #T_57b04_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.7%, transparent 26.7%);
# }
# #T_57b04_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.2%, transparent 20.2%);
# }
# #T_57b04_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.6%, transparent 24.6%);
# }
# #T_57b04_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.1%, transparent 72.1%);
# }
# #T_57b04_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.3%, transparent 44.3%);
# }
# #T_57b04_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.0%, transparent 35.0%);
# }
# #T_57b04_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.0%, transparent 37.0%);
# }
# #T_57b04_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.6%, transparent 33.6%);
# }
# #T_57b04_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 36.1%, transparent 36.1%);
# }
# #T_57b04_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 45.7%, transparent 45.7%);
# }
# #T_57b04_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.2%, transparent 35.2%);
# }
# #T_57b04_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.4%, transparent 46.4%);
# }
# #T_57b04_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.1%, transparent 37.1%);
# }
# #T_57b04_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.1%, transparent 74.1%);
# }
# #T_57b04_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.1%, transparent 64.1%);
# }
# #T_57b04_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.5%, transparent 56.5%);
# }
# #T_57b04_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.9%, transparent 62.9%);
# }
# #T_57b04_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.3%, transparent 89.3%);
# }
# #T_57b04_row10_col1, #T_57b04_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.3%, transparent 77.3%);
# }
# #T_57b04_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.2%, transparent 43.2%);
# }
# #T_57b04_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 70.7%, transparent 70.7%);
# }
# #T_57b04_row11_col0, #T_57b04_row28_col3, #T_57b04_row29_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 84.3%, transparent 84.3%);
# }
# #T_57b04_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.5%, transparent 48.5%);
# }
# #T_57b04_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.8%, transparent 71.8%);
# }
# #T_57b04_row12_col0, #T_57b04_row16_col0, #T_57b04_row17_col0, #T_57b04_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.9%, transparent 95.9%);
# }
# #T_57b04_row12_col1, #T_57b04_row15_col1, #T_57b04_row27_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.9%, transparent 83.9%);
# }
# #T_57b04_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.9%, transparent 50.9%);
# }
# #T_57b04_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.1%, transparent 77.1%);
# }
# #T_57b04_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.0%, transparent 97.0%);
#   background-color: yellow;
# }
# #T_57b04_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.2%, transparent 83.2%);
#   background-color: yellow;
# }
# #T_57b04_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 55.1%, transparent 55.1%);
#   background-color: yellow;
# }
# #T_57b04_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.9%, transparent 77.9%);
#   background-color: yellow;
# }
# #T_57b04_row14_col0, #T_57b04_row21_col0, #T_57b04_row23_col0, #T_57b04_row29_col0, #T_57b04_row47_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.4%, transparent 93.4%);
# }
# #T_57b04_row14_col1, #T_57b04_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 84.2%, transparent 84.2%);
# }
# #T_57b04_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.7%, transparent 57.7%);
# }
# #T_57b04_row14_col3, #T_57b04_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.6%, transparent 78.6%);
# }
# #T_57b04_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.8%, transparent 89.8%);
# }
# #T_57b04_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.2%, transparent 59.2%);
# }
# #T_57b04_row16_col1, #T_57b04_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.1%, transparent 86.1%);
# }
# #T_57b04_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.5%, transparent 51.5%);
# }
# #T_57b04_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.9%, transparent 78.9%);
# }
# #T_57b04_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 55.7%, transparent 55.7%);
# }
# #T_57b04_row17_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_57b04_row18_col0, #T_57b04_row26_col0, #T_57b04_row51_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.9%, transparent 92.9%);
# }
# #T_57b04_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.5%, transparent 59.5%);
# }
# #T_57b04_row18_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 79.6%, transparent 79.6%);
# }
# #T_57b04_row19_col0, #T_57b04_row22_col0, #T_57b04_row41_col0, #T_57b04_row49_col0, #T_57b04_row49_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 94.9%, transparent 94.9%);
# }
# #T_57b04_row19_col1, #T_57b04_row40_col3, #T_57b04_row41_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.4%, transp

# %%
# Baseline
df = map.copy()
df = df[df.index.str.contains('baseline_') | (df.index == 'base_yolov8n') |  (df.index == name_base_model)]
df.style.apply(highlight_base_model_row, axis=1).apply(highlight_better, axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_56b6e_row9_col0, #T_56b6e_row9_col1, #T_56b6e_row9_col2, #T_56b6e_row9_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_56b6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56b6e_level0_col0" class="col_heading level0 col0" >test_synth</th>
#       <th id="T_56b6e_level0_col1" class="col_heading level0 col1" >test_real_nominal</th>
#       <th id="T_56b6e_level0_col2" class="col_heading level0 col2" >test_real_edge</th>
#       <th id="T_56b6e_level0_col3" class="col_heading level0 col3" >test_real</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrics</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56b6e_level0_row0" class="row_heading level0 row0" >baseline_yolov3</th>
#       <td id="T_56b6e_row0_col0" class="data row0 col0" >0.684</td>
#       <td id="T_56b6e_row0_col1" class="data row0 col1" >0.492</td>
#       <td id="T_56b6e_row0_col2" class="data row0 col2" >0.233</td>
#       <td id="T_56b6e_row0_col3" class="data row0 col3" >0.448</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row1" class="row_heading level0 row1" >baseline_ssd</th>
#       <td id="T_56b6e_row1_col0" class="data row1 col0" >0.674</td>
#       <td id="T_56b6e_row1_col1" class="data row1 col1" >0.508</td>
#       <td id="T_56b6e_row1_col2" class="data row1 col2" >0.261</td>
#       <td id="T_56b6e_row1_col3" class="data row1 col3" >0.464</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row2" class="row_heading level0 row2" >baseline_yolov6n</th>
#       <td id="T_56b6e_row2_col0" class="data row2 col0" >0.722</td>
#       <td id="T_56b6e_row2_col1" class="data row2 col1" >0.524</td>
#       <td id="T_56b6e_row2_col2" class="data row2 col2" >0.219</td>
#       <td id="T_56b6e_row2_col3" class="data row2 col3" >0.473</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row3" class="row_heading level0 row3" >baseline_yolov7t</th>
#       <td id="T_56b6e_row3_col0" class="data row3 col0" >0.687</td>
#       <td id="T_56b6e_row3_col1" class="data row3 col1" >0.524</td>
#       <td id="T_56b6e_row3_col2" class="data row3 col2" >0.316</td>
#       <td id="T_56b6e_row3_col3" class="data row3 col3" >0.488</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row4" class="row_heading level0 row4" >baseline_yolov5n</th>
#       <td id="T_56b6e_row4_col0" class="data row4 col0" >0.706</td>
#       <td id="T_56b6e_row4_col1" class="data row4 col1" >0.540</td>
#       <td id="T_56b6e_row4_col2" class="data row4 col2" >0.302</td>
#       <td id="T_56b6e_row4_col3" class="data row4 col3" >0.499</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row5" class="row_heading level0 row5" >baseline_faster_rcnn</th>
#       <td id="T_56b6e_row5_col0" class="data row5 col0" >0.719</td>
#       <td id="T_56b6e_row5_col1" class="data row5 col1" >0.565</td>
#       <td id="T_56b6e_row5_col2" class="data row5 col2" >0.286</td>
#       <td id="T_56b6e_row5_col3" class="data row5 col3" >0.517</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row6" class="row_heading level0 row6" >baseline_centernet</th>
#       <td id="T_56b6e_row6_col0" class="data row6 col0" >0.801</td>
#       <td id="T_56b6e_row6_col1" class="data row6 col1" >0.613</td>
#       <td id="T_56b6e_row6_col2" class="data row6 col2" >0.218</td>
#       <td id="T_56b6e_row6_col3" class="data row6 col3" >0.546</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row7" class="row_heading level0 row7" >baseline_retinanet</th>
#       <td id="T_56b6e_row7_col0" class="data row7 col0" >0.659</td>
#       <td id="T_56b6e_row7_col1" class="data row7 col1" >0.593</td>
#       <td id="T_56b6e_row7_col2" class="data row7 col2" >0.331</td>
#       <td id="T_56b6e_row7_col3" class="data row7 col3" >0.549</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row8" class="row_heading level0 row8" >base_yolov8n</th>
#       <td id="T_56b6e_row8_col0" class="data row8 col0" >0.749</td>
#       <td id="T_56b6e_row8_col1" class="data row8 col1" >0.588</td>
#       <td id="T_56b6e_row8_col2" class="data row8 col2" >0.374</td>
#       <td id="T_56b6e_row8_col3" class="data row8 col3" >0.552</td>
#     </tr>
#     <tr>
#       <th id="T_56b6e_level0_row9" class="row_heading level0 row9" >base_yolov8n_1280</th>
#       <td id="T_56b6e_row9_col0" class="data row9 col0" >0.850</td>
#       <td id="T_56b6e_row9_col1" class="data row9 col1" >0.719</td>
#       <td id="T_56b6e_row9_col2" class="data row9 col2" >0.403</td>
#       <td id="T_56b6e_row9_col3" class="data row9 col3" >0.666</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Orin
df = map.copy()
df = df[df.index.str.contains('base_') | (df.index == name_base_model)]
df.style.apply(highlight_base_model_row, axis=1).apply(highlight_better, axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_761f3_row1_col0, #T_761f3_row1_col1, #T_761f3_row1_col2, #T_761f3_row1_col3 {
#   background-color: yellow;
# }
# #T_761f3_row2_col1, #T_761f3_row2_col2, #T_761f3_row2_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_761f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_761f3_level0_col0" class="col_heading level0 col0" >test_synth</th>
#       <th id="T_761f3_level0_col1" class="col_heading level0 col1" >test_real_nominal</th>
#       <th id="T_761f3_level0_col2" class="col_heading level0 col2" >test_real_edge</th>
#       <th id="T_761f3_level0_col3" class="col_heading level0 col3" >test_real</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrics</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_761f3_level0_row0" class="row_heading level0 row0" >base_yolov8n</th>
#       <td id="T_761f3_row0_col0" class="data row0 col0" >0.749</td>
#       <td id="T_761f3_row0_col1" class="data row0 col1" >0.588</td>
#       <td id="T_761f3_row0_col2" class="data row0 col2" >0.374</td>
#       <td id="T_761f3_row0_col3" class="data row0 col3" >0.552</td>
#     </tr>
#     <tr>
#       <th id="T_761f3_level0_row1" class="row_heading level0 row1" >base_yolov8n_1280</th>
#       <td id="T_761f3_row1_col0" class="data row1 col0" >0.850</td>
#       <td id="T_761f3_row1_col1" class="data row1 col1" >0.719</td>
#       <td id="T_761f3_row1_col2" class="data row1 col2" >0.403</td>
#       <td id="T_761f3_row1_col3" class="data row1 col3" >0.666</td>
#     </tr>
#     <tr>
#       <th id="T_761f3_level0_row2" class="row_heading level0 row2" >base_yolov8n-p2_1280</th>
#       <td id="T_761f3_row2_col0" class="data row2 col0" >0.845</td>
#       <td id="T_761f3_row2_col1" class="data row2 col1" >0.742</td>
#       <td id="T_761f3_row2_col2" class="data row2 col2" >0.434</td>
#       <td id="T_761f3_row2_col3" class="data row2 col3" >0.688</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Album
df = map.copy()
df = df[df.index.str.contains('aug_') | (df.index == name_base_model)]
df.style.apply(highlight_base_model_row, axis=1).apply(highlight_better, axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_2b7f7_row0_col0, #T_2b7f7_row0_col1, #T_2b7f7_row0_col2, #T_2b7f7_row0_col3 {
#   background-color: yellow;
# }
# #T_2b7f7_row1_col0, #T_2b7f7_row1_col1, #T_2b7f7_row1_col2, #T_2b7f7_row1_col3, #T_2b7f7_row2_col1, #T_2b7f7_row2_col2, #T_2b7f7_row2_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_2b7f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b7f7_level0_col0" class="col_heading level0 col0" >test_synth</th>
#       <th id="T_2b7f7_level0_col1" class="col_heading level0 col1" >test_real_nominal</th>
#       <th id="T_2b7f7_level0_col2" class="col_heading level0 col2" >test_real_edge</th>
#       <th id="T_2b7f7_level0_col3" class="col_heading level0 col3" >test_real</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrics</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b7f7_level0_row0" class="row_heading level0 row0" >base_yolov8n_1280</th>
#       <td id="T_2b7f7_row0_col0" class="data row0 col0" >0.850</td>
#       <td id="T_2b7f7_row0_col1" class="data row0 col1" >0.719</td>
#       <td id="T_2b7f7_row0_col2" class="data row0 col2" >0.403</td>
#       <td id="T_2b7f7_row0_col3" class="data row0 col3" >0.666</td>
#     </tr>
#     <tr>
#       <th id="T_2b7f7_level0_row1" class="row_heading level0 row1" >aug_yolov8n_aug5_1280</th>
#       <td id="T_2b7f7_row1_col0" class="data row1 col0" >0.853</td>
#       <td id="T_2b7f7_row1_col1" class="data row1 col1" >0.750</td>
#       <td id="T_2b7f7_row1_col2" class="data row1 col2" >0.502</td>
#       <td id="T_2b7f7_row1_col3" class="data row1 col3" >0.709</td>
#     </tr>
#     <tr>
#       <th id="T_2b7f7_level0_row2" class="row_heading level0 row2" >aug_yolov8n_aug10_1280</th>
#       <td id="T_2b7f7_row2_col0" class="data row2 col0" >0.848</td>
#       <td id="T_2b7f7_row2_col1" class="data row2 col1" >0.750</td>
#       <td id="T_2b7f7_row2_col2" class="data row2 col2" >0.550</td>
#       <td id="T_2b7f7_row2_col3" class="data row2 col3" >0.717</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Attention
df = map.copy()
df = df[df.index.str.contains('att_') | (df.index == name_base_model)]
df.style.apply(highlight_base_model_row, axis=1).apply(highlight_better, axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_10b6c_row0_col1, #T_10b6c_row2_col1, #T_10b6c_row2_col3, #T_10b6c_row3_col1, #T_10b6c_row3_col2, #T_10b6c_row3_col3, #T_10b6c_row4_col1, #T_10b6c_row4_col2, #T_10b6c_row4_col3, #T_10b6c_row5_col1, #T_10b6c_row5_col2, #T_10b6c_row5_col3, #T_10b6c_row6_col1, #T_10b6c_row6_col2, #T_10b6c_row6_col3, #T_10b6c_row7_col1, #T_10b6c_row7_col2, #T_10b6c_row7_col3, #T_10b6c_row8_col0, #T_10b6c_row8_col1, #T_10b6c_row8_col2, #T_10b6c_row8_col3, #T_10b6c_row9_col0, #T_10b6c_row9_col1, #T_10b6c_row9_col2, #T_10b6c_row9_col3, #T_10b6c_row10_col0, #T_10b6c_row10_col1, #T_10b6c_row10_col2, #T_10b6c_row10_col3, #T_10b6c_row11_col1, #T_10b6c_row11_col2, #T_10b6c_row11_col3 {
#   background-color: red;
# }
# #T_10b6c_row1_col0, #T_10b6c_row1_col1, #T_10b6c_row1_col2, #T_10b6c_row1_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_10b6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10b6c_level0_col0" class="col_heading level0 col0" >test_synth</th>
#       <th id="T_10b6c_level0_col1" class="col_heading level0 col1" >test_real_nominal</th>
#       <th id="T_10b6c_level0_col2" class="col_heading level0 col2" >test_real_edge</th>
#       <th id="T_10b6c_level0_col3" class="col_heading level0 col3" >test_real</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrics</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10b6c_level0_row0" class="row_heading level0 row0" >att_yolov8n_cpca_1280</th>
#       <td id="T_10b6c_row0_col0" class="data row0 col0" >0.848</td>
#       <td id="T_10b6c_row0_col1" class="data row0 col1" >0.721</td>
#       <td id="T_10b6c_row0_col2" class="data row0 col2" >0.389</td>
#       <td id="T_10b6c_row0_col3" class="data row0 col3" >0.664</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row1" class="row_heading level0 row1" >base_yolov8n_1280</th>
#       <td id="T_10b6c_row1_col0" class="data row1 col0" >0.850</td>
#       <td id="T_10b6c_row1_col1" class="data row1 col1" >0.719</td>
#       <td id="T_10b6c_row1_col2" class="data row1 col2" >0.403</td>
#       <td id="T_10b6c_row1_col3" class="data row1 col3" >0.666</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row2" class="row_heading level0 row2" >att_yolov8n_se_1280</th>
#       <td id="T_10b6c_row2_col0" class="data row2 col0" >0.848</td>
#       <td id="T_10b6c_row2_col1" class="data row2 col1" >0.727</td>
#       <td id="T_10b6c_row2_col2" class="data row2 col2" >0.391</td>
#       <td id="T_10b6c_row2_col3" class="data row2 col3" >0.669</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row3" class="row_heading level0 row3" >att_yolov8n_eca_1280</th>
#       <td id="T_10b6c_row3_col0" class="data row3 col0" >0.842</td>
#       <td id="T_10b6c_row3_col1" class="data row3 col1" >0.722</td>
#       <td id="T_10b6c_row3_col2" class="data row3 col2" >0.418</td>
#       <td id="T_10b6c_row3_col3" class="data row3 col3" >0.671</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row4" class="row_heading level0 row4" >att_yolov8n_ema_1280</th>
#       <td id="T_10b6c_row4_col0" class="data row4 col0" >0.843</td>
#       <td id="T_10b6c_row4_col1" class="data row4 col1" >0.729</td>
#       <td id="T_10b6c_row4_col2" class="data row4 col2" >0.419</td>
#       <td id="T_10b6c_row4_col3" class="data row4 col3" >0.677</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row5" class="row_heading level0 row5" >att_yolov8n_lska_1280</th>
#       <td id="T_10b6c_row5_col0" class="data row5 col0" >0.847</td>
#       <td id="T_10b6c_row5_col1" class="data row5 col1" >0.732</td>
#       <td id="T_10b6c_row5_col2" class="data row5 col2" >0.410</td>
#       <td id="T_10b6c_row5_col3" class="data row5 col3" >0.679</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row6" class="row_heading level0 row6" >att_yolov8n_sa_1280</th>
#       <td id="T_10b6c_row6_col0" class="data row6 col0" >0.847</td>
#       <td id="T_10b6c_row6_col1" class="data row6 col1" >0.737</td>
#       <td id="T_10b6c_row6_col2" class="data row6 col2" >0.429</td>
#       <td id="T_10b6c_row6_col3" class="data row6 col3" >0.685</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row7" class="row_heading level0 row7" >att_yolov8n_cbam_1280</th>
#       <td id="T_10b6c_row7_col0" class="data row7 col0" >0.850</td>
#       <td id="T_10b6c_row7_col1" class="data row7 col1" >0.741</td>
#       <td id="T_10b6c_row7_col2" class="data row7 col2" >0.428</td>
#       <td id="T_10b6c_row7_col3" class="data row7 col3" >0.686</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row8" class="row_heading level0 row8" >att_yolov8n_gam_1280</th>
#       <td id="T_10b6c_row8_col0" class="data row8 col0" >0.853</td>
#       <td id="T_10b6c_row8_col1" class="data row8 col1" >0.738</td>
#       <td id="T_10b6c_row8_col2" class="data row8 col2" >0.429</td>
#       <td id="T_10b6c_row8_col3" class="data row8 col3" >0.687</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row9" class="row_heading level0 row9" >att_yolov8n_ta_1280</th>
#       <td id="T_10b6c_row9_col0" class="data row9 col0" >0.851</td>
#       <td id="T_10b6c_row9_col1" class="data row9 col1" >0.741</td>
#       <td id="T_10b6c_row9_col2" class="data row9 col2" >0.434</td>
#       <td id="T_10b6c_row9_col3" class="data row9 col3" >0.688</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row10" class="row_heading level0 row10" >att_yolov8n_lsk_1280</th>
#       <td id="T_10b6c_row10_col0" class="data row10 col0" >0.852</td>
#       <td id="T_10b6c_row10_col1" class="data row10 col1" >0.744</td>
#       <td id="T_10b6c_row10_col2" class="data row10 col2" >0.449</td>
#       <td id="T_10b6c_row10_col3" class="data row10 col3" >0.694</td>
#     </tr>
#     <tr>
#       <th id="T_10b6c_level0_row11" class="row_heading level0 row11" >att_yolov8n_ese_1280</th>
#       <td id="T_10b6c_row11_col0" class="data row11 col0" >0.847</td>
#       <td id="T_10b6c_row11_col1" class="data row11 col1" >0.745</td>
#       <td id="T_10b6c_row11_col2" class="data row11 col2" >0.454</td>
#       <td id="T_10b6c_row11_col3" class="data row11 col3" >0.695</td>
#     </tr>
#   </tbody>
# </table>

# %%
# IoU
df = map.copy()
df = df[df.index.str.contains('iou_') | (df.index == name_base_model)]
df.style.apply(highlight_base_model_row, axis=1).apply(highlight_better, axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_d3f9f_row0_col2, #T_d3f9f_row3_col1, #T_d3f9f_row3_col2, #T_d3f9f_row3_col3, #T_d3f9f_row4_col1, #T_d3f9f_row4_col2, #T_d3f9f_row4_col3, #T_d3f9f_row5_col1, #T_d3f9f_row5_col2, #T_d3f9f_row5_col3, #T_d3f9f_row6_col1, #T_d3f9f_row6_col2, #T_d3f9f_row6_col3, #T_d3f9f_row7_col1, #T_d3f9f_row7_col2, #T_d3f9f_row7_col3, #T_d3f9f_row8_col1, #T_d3f9f_row8_col2, #T_d3f9f_row8_col3, #T_d3f9f_row9_col0, #T_d3f9f_row9_col1, #T_d3f9f_row9_col2, #T_d3f9f_row9_col3 {
#   background-color: red;
# }
# #T_d3f9f_row2_col0, #T_d3f9f_row2_col1, #T_d3f9f_row2_col2, #T_d3f9f_row2_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_d3f9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3f9f_level0_col0" class="col_heading level0 col0" >test_synth</th>
#       <th id="T_d3f9f_level0_col1" class="col_heading level0 col1" >test_real_nominal</th>
#       <th id="T_d3f9f_level0_col2" class="col_heading level0 col2" >test_real_edge</th>
#       <th id="T_d3f9f_level0_col3" class="col_heading level0 col3" >test_real</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrics</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3f9f_level0_row0" class="row_heading level0 row0" >iou_yolov8n_NWD_1280</th>
#       <td id="T_d3f9f_row0_col0" class="data row0 col0" >0.805</td>
#       <td id="T_d3f9f_row0_col1" class="data row0 col1" >0.667</td>
#       <td id="T_d3f9f_row0_col2" class="data row0 col2" >0.408</td>
#       <td id="T_d3f9f_row0_col3" class="data row0 col3" >0.624</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row1" class="row_heading level0 row1" >iou_yolov8n_WIoU_1280</th>
#       <td id="T_d3f9f_row1_col0" class="data row1 col0" >0.825</td>
#       <td id="T_d3f9f_row1_col1" class="data row1 col1" >0.703</td>
#       <td id="T_d3f9f_row1_col2" class="data row1 col2" >0.381</td>
#       <td id="T_d3f9f_row1_col3" class="data row1 col3" >0.649</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row2" class="row_heading level0 row2" >base_yolov8n_1280</th>
#       <td id="T_d3f9f_row2_col0" class="data row2 col0" >0.850</td>
#       <td id="T_d3f9f_row2_col1" class="data row2 col1" >0.719</td>
#       <td id="T_d3f9f_row2_col2" class="data row2 col2" >0.403</td>
#       <td id="T_d3f9f_row2_col3" class="data row2 col3" >0.666</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row3" class="row_heading level0 row3" >iou_yolov8n_EIoU_1280</th>
#       <td id="T_d3f9f_row3_col0" class="data row3 col0" >0.843</td>
#       <td id="T_d3f9f_row3_col1" class="data row3 col1" >0.722</td>
#       <td id="T_d3f9f_row3_col2" class="data row3 col2" >0.412</td>
#       <td id="T_d3f9f_row3_col3" class="data row3 col3" >0.668</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row4" class="row_heading level0 row4" >iou_yolov8n_MDPIoU1_1280</th>
#       <td id="T_d3f9f_row4_col0" class="data row4 col0" >0.816</td>
#       <td id="T_d3f9f_row4_col1" class="data row4 col1" >0.730</td>
#       <td id="T_d3f9f_row4_col2" class="data row4 col2" >0.440</td>
#       <td id="T_d3f9f_row4_col3" class="data row4 col3" >0.682</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row5" class="row_heading level0 row5" >iou_yolov8n_MDPIoU2_1280</th>
#       <td id="T_d3f9f_row5_col0" class="data row5 col0" >0.847</td>
#       <td id="T_d3f9f_row5_col1" class="data row5 col1" >0.734</td>
#       <td id="T_d3f9f_row5_col2" class="data row5 col2" >0.429</td>
#       <td id="T_d3f9f_row5_col3" class="data row5 col3" >0.683</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row6" class="row_heading level0 row6" >iou_yolov8n_GIoU_1280</th>
#       <td id="T_d3f9f_row6_col0" class="data row6 col0" >0.845</td>
#       <td id="T_d3f9f_row6_col1" class="data row6 col1" >0.735</td>
#       <td id="T_d3f9f_row6_col2" class="data row6 col2" >0.432</td>
#       <td id="T_d3f9f_row6_col3" class="data row6 col3" >0.684</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row7" class="row_heading level0 row7" >iou_yolov8n_SIoU_1280</th>
#       <td id="T_d3f9f_row7_col0" class="data row7 col0" >0.845</td>
#       <td id="T_d3f9f_row7_col1" class="data row7 col1" >0.739</td>
#       <td id="T_d3f9f_row7_col2" class="data row7 col2" >0.422</td>
#       <td id="T_d3f9f_row7_col3" class="data row7 col3" >0.686</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row8" class="row_heading level0 row8" >iou_yolov8n_ShapeIoU_1280</th>
#       <td id="T_d3f9f_row8_col0" class="data row8 col0" >0.849</td>
#       <td id="T_d3f9f_row8_col1" class="data row8 col1" >0.740</td>
#       <td id="T_d3f9f_row8_col2" class="data row8 col2" >0.434</td>
#       <td id="T_d3f9f_row8_col3" class="data row8 col3" >0.687</td>
#     </tr>
#     <tr>
#       <th id="T_d3f9f_level0_row9" class="row_heading level0 row9" >iou_yolov8n_DIoU_1280</th>
#       <td id="T_d3f9f_row9_col0" class="data row9 col0" >0.852</td>
#       <td id="T_d3f9f_row9_col1" class="data row9 col1" >0.742</td>
#       <td id="T_d3f9f_row9_col2" class="data row9 col2" >0.446</td>
#       <td id="T_d3f9f_row9_col3" class="data row9 col3" >0.693</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Neck
df = map.copy()
df = df[df.index.str.contains('neck_') | (df.index == name_base_model)]
df.style.apply(highlight_base_model_row, axis=1).apply(highlight_better, axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_2e585_row0_col0, #T_2e585_row0_col1, #T_2e585_row0_col2, #T_2e585_row0_col3 {
#   background-color: yellow;
# }
# #T_2e585_row1_col1, #T_2e585_row1_col2, #T_2e585_row1_col3, #T_2e585_row2_col1, #T_2e585_row2_col2, #T_2e585_row2_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_2e585">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e585_level0_col0" class="col_heading level0 col0" >test_synth</th>
#       <th id="T_2e585_level0_col1" class="col_heading level0 col1" >test_real_nominal</th>
#       <th id="T_2e585_level0_col2" class="col_heading level0 col2" >test_real_edge</th>
#       <th id="T_2e585_level0_col3" class="col_heading level0 col3" >test_real</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrics</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e585_level0_row0" class="row_heading level0 row0" >base_yolov8n_1280</th>
#       <td id="T_2e585_row0_col0" class="data row0 col0" >0.850</td>
#       <td id="T_2e585_row0_col1" class="data row0 col1" >0.719</td>
#       <td id="T_2e585_row0_col2" class="data row0 col2" >0.403</td>
#       <td id="T_2e585_row0_col3" class="data row0 col3" >0.666</td>
#     </tr>
#     <tr>
#       <th id="T_2e585_level0_row1" class="row_heading level0 row1" >neck_yolov8n_afpn_1280</th>
#       <td id="T_2e585_row1_col0" class="data row1 col0" >0.847</td>
#       <td id="T_2e585_row1_col1" class="data row1 col1" >0.744</td>
#       <td id="T_2e585_row1_col2" class="data row1 col2" >0.416</td>
#       <td id="T_2e585_row1_col3" class="data row1 col3" >0.688</td>
#     </tr>
#     <tr>
#       <th id="T_2e585_level0_row2" class="row_heading level0 row2" >neck_yolov8n_bifpn_1280</th>
#       <td id="T_2e585_row2_col0" class="data row2 col0" >0.846</td>
#       <td id="T_2e585_row2_col1" class="data row2 col1" >0.740</td>
#       <td id="T_2e585_row2_col2" class="data row2 col2" >0.450</td>
#       <td id="T_2e585_row2_col3" class="data row2 col3" >0.690</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Merge
df = map.copy()
df = df[df.index.str.contains('merge_') | (df.index == name_base_model)]
df.style.apply(highlight_base_model_row, axis=1).apply(highlight_better, axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_0de26_row1_col0, #T_0de26_row1_col1, #T_0de26_row1_col2, #T_0de26_row1_col3 {
#   background-color: yellow;
# }
# #T_0de26_row2_col1, #T_0de26_row2_col2, #T_0de26_row2_col3, #T_0de26_row3_col1, #T_0de26_row3_col2, #T_0de26_row3_col3, #T_0de26_row4_col1, #T_0de26_row4_col3, #T_0de26_row5_col0, #T_0de26_row5_col1, #T_0de26_row5_col2, #T_0de26_row5_col3, #T_0de26_row6_col1, #T_0de26_row6_col2, #T_0de26_row6_col3, #T_0de26_row7_col1, #T_0de26_row7_col2, #T_0de26_row7_col3, #T_0de26_row8_col1, #T_0de26_row8_col2, #T_0de26_row8_col3, #T_0de26_row9_col1, #T_0de26_row9_col2, #T_0de26_row9_col3, #T_0de26_row10_col1, #T_0de26_row10_col2, #T_0de26_row10_col3, #T_0de26_row11_col1, #T_0de26_row11_col2, #T_0de26_row11_col3, #T_0de26_row12_col1, #T_0de26_row12_col2, #T_0de26_row12_col3, #T_0de26_row13_col1, #T_0de26_row13_col2, #T_0de26_row13_col3, #T_0de26_row14_col1, #T_0de26_row14_col2, #T_0de26_row14_col3, #T_0de26_row15_col0, #T_0de26_row15_col1, #T_0de26_row15_col2, #T_0de26_row15_col3, #T_0de26_row16_col0, #T_0de26_row16_col1, #T_0de26_row16_col2, #T_0de26_row16_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_0de26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0de26_level0_col0" class="col_heading level0 col0" >test_synth</th>
#       <th id="T_0de26_level0_col1" class="col_heading level0 col1" >test_real_nominal</th>
#       <th id="T_0de26_level0_col2" class="col_heading level0 col2" >test_real_edge</th>
#       <th id="T_0de26_level0_col3" class="col_heading level0 col3" >test_real</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metrics</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0de26_level0_row0" class="row_heading level0 row0" >merge_yolov8n-p2_afpn_1280</th>
#       <td id="T_0de26_row0_col0" class="data row0 col0" >0.835</td>
#       <td id="T_0de26_row0_col1" class="data row0 col1" >0.703</td>
#       <td id="T_0de26_row0_col2" class="data row0 col2" >0.363</td>
#       <td id="T_0de26_row0_col3" class="data row0 col3" >0.646</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row1" class="row_heading level0 row1" >base_yolov8n_1280</th>
#       <td id="T_0de26_row1_col0" class="data row1 col0" >0.850</td>
#       <td id="T_0de26_row1_col1" class="data row1 col1" >0.719</td>
#       <td id="T_0de26_row1_col2" class="data row1 col2" >0.403</td>
#       <td id="T_0de26_row1_col3" class="data row1 col3" >0.666</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row2" class="row_heading level0 row2" >merge_yolov8n-p2_lsk_bifpn_1280</th>
#       <td id="T_0de26_row2_col0" class="data row2 col0" >0.836</td>
#       <td id="T_0de26_row2_col1" class="data row2 col1" >0.721</td>
#       <td id="T_0de26_row2_col2" class="data row2 col2" >0.417</td>
#       <td id="T_0de26_row2_col3" class="data row2 col3" >0.668</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row3" class="row_heading level0 row3" >merge_yolov8n_lsk_bifpn_DIoU_1280</th>
#       <td id="T_0de26_row3_col0" class="data row3 col0" >0.848</td>
#       <td id="T_0de26_row3_col1" class="data row3 col1" >0.727</td>
#       <td id="T_0de26_row3_col2" class="data row3 col2" >0.405</td>
#       <td id="T_0de26_row3_col3" class="data row3 col3" >0.670</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row4" class="row_heading level0 row4" >merge_yolov8n_lsk_bifpn_1280</th>
#       <td id="T_0de26_row4_col0" class="data row4 col0" >0.846</td>
#       <td id="T_0de26_row4_col1" class="data row4 col1" >0.728</td>
#       <td id="T_0de26_row4_col2" class="data row4 col2" >0.400</td>
#       <td id="T_0de26_row4_col3" class="data row4 col3" >0.672</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row5" class="row_heading level0 row5" >merge_yolov8n-p2_lsk_DIoU_1280</th>
#       <td id="T_0de26_row5_col0" class="data row5 col0" >0.853</td>
#       <td id="T_0de26_row5_col1" class="data row5 col1" >0.726</td>
#       <td id="T_0de26_row5_col2" class="data row5 col2" >0.423</td>
#       <td id="T_0de26_row5_col3" class="data row5 col3" >0.676</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row6" class="row_heading level0 row6" >merge_yolov8n-p2_lsk_1280</th>
#       <td id="T_0de26_row6_col0" class="data row6 col0" >0.843</td>
#       <td id="T_0de26_row6_col1" class="data row6 col1" >0.732</td>
#       <td id="T_0de26_row6_col2" class="data row6 col2" >0.420</td>
#       <td id="T_0de26_row6_col3" class="data row6 col3" >0.678</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row7" class="row_heading level0 row7" >merge_yolov8n-p2_DIoU_1280</th>
#       <td id="T_0de26_row7_col0" class="data row7 col0" >0.842</td>
#       <td id="T_0de26_row7_col1" class="data row7 col1" >0.738</td>
#       <td id="T_0de26_row7_col2" class="data row7 col2" >0.411</td>
#       <td id="T_0de26_row7_col3" class="data row7 col3" >0.682</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row8" class="row_heading level0 row8" >merge_yolov8n_bifpn_DIoU_1280</th>
#       <td id="T_0de26_row8_col0" class="data row8 col0" >0.843</td>
#       <td id="T_0de26_row8_col1" class="data row8 col1" >0.733</td>
#       <td id="T_0de26_row8_col2" class="data row8 col2" >0.441</td>
#       <td id="T_0de26_row8_col3" class="data row8 col3" >0.684</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row9" class="row_heading level0 row9" >merge_yolov8n-p2_bifpn_DIoU_1280</th>
#       <td id="T_0de26_row9_col0" class="data row9 col0" >0.839</td>
#       <td id="T_0de26_row9_col1" class="data row9 col1" >0.736</td>
#       <td id="T_0de26_row9_col2" class="data row9 col2" >0.442</td>
#       <td id="T_0de26_row9_col3" class="data row9 col3" >0.686</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row10" class="row_heading level0 row10" >merge_yolov8n-p2_bifpn_1280</th>
#       <td id="T_0de26_row10_col0" class="data row10 col0" >0.845</td>
#       <td id="T_0de26_row10_col1" class="data row10 col1" >0.738</td>
#       <td id="T_0de26_row10_col2" class="data row10 col2" >0.434</td>
#       <td id="T_0de26_row10_col3" class="data row10 col3" >0.686</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row11" class="row_heading level0 row11" >merge_yolov8n_lsk_DIoU_1280</th>
#       <td id="T_0de26_row11_col0" class="data row11 col0" >0.847</td>
#       <td id="T_0de26_row11_col1" class="data row11 col1" >0.737</td>
#       <td id="T_0de26_row11_col2" class="data row11 col2" >0.456</td>
#       <td id="T_0de26_row11_col3" class="data row11 col3" >0.690</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row12" class="row_heading level0 row12" >merge_yolov8n-p2_lsk_bifpn_DIoU_1280</th>
#       <td id="T_0de26_row12_col0" class="data row12 col0" >0.849</td>
#       <td id="T_0de26_row12_col1" class="data row12 col1" >0.742</td>
#       <td id="T_0de26_row12_col2" class="data row12 col2" >0.436</td>
#       <td id="T_0de26_row12_col3" class="data row12 col3" >0.692</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row13" class="row_heading level0 row13" >merge_yolov8n-p2_lsk_bifpn_DIoU_aug20_1280</th>
#       <td id="T_0de26_row13_col0" class="data row13 col0" >0.847</td>
#       <td id="T_0de26_row13_col1" class="data row13 col1" >0.747</td>
#       <td id="T_0de26_row13_col2" class="data row13 col2" >0.554</td>
#       <td id="T_0de26_row13_col3" class="data row13 col3" >0.716</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row14" class="row_heading level0 row14" >merge_yolov8n-p2_lsk_bifpn_DIoU_aug15_1280</th>
#       <td id="T_0de26_row14_col0" class="data row14 col0" >0.846</td>
#       <td id="T_0de26_row14_col1" class="data row14 col1" >0.754</td>
#       <td id="T_0de26_row14_col2" class="data row14 col2" >0.537</td>
#       <td id="T_0de26_row14_col3" class="data row14 col3" >0.719</td>
#     </tr>
#     <tr>
#       <th id="T_0de26_level0_row15" class="row_heading level0 row15" >merge_yolov8n-p2_lsk_bifpn_DIoU_aug5_1280</th>
#       <td id="T_0de26_row15_col0" class="data row15 col0" >0.853<

# %%
# from src.utils.metric import ensemble_coco_metrics

# path_preds_json_list = [
#     # 'runs/ultralytics/merge/yolov8n_cpca_SIoU_aug1/test/test_real_edge/predictions_modified.json',
#     'runs/ultralytics/merge/yolov8n_lska_WIoU_aug1/test/test_real_edge/predictions_modified.json',
#     'runs/ultralytics/merge/yolov8n_ta_SIoU_aug1/test/test_real_edge/predictions_modified.json'
# ]
# path_instance_json = 'datasets/lard/annotations/instances_test_real_edge.json'
# all_metrics = ensemble_coco_metrics(path_preds_json_list, path_instance_json, verbose=False, ensemble_method='nmw')  # ['nms', 'soft', 'nmw', 'wbf']

# %%
# def highlight_last_col_max(row):
#     last_col = row.iloc[-1]  # 使用 iloc 获取最后一列的值
#     is_max = last_col > row.iloc[:-1].max()  # 比较最后一列的值与其他列的最大值
#     return ['background-color: red' if (col == last_col and is_max) else '' for col in row]
# all_metrics.style.apply(highlight_last_col_max, axis=1)
