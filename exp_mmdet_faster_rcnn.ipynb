# %% [markdown]
# # 训练

# %%
# ./scripts/mmdet_train.sh faster_rcnn 10

# %%
gpu_id = 0

# %% [markdown]
# # 变量定义

# %%
import glob
import os

# 参数
model_name = 'faster_rcnn'
model_stru = ''
model_cfg = ''  # _train_val _train_val_aug
img_size = 1333
exp_name = f'{model_name}{model_stru}{model_cfg}_{img_size}'

# 路径
cfg_path = f'cfg/mmdet/{model_name}_{img_size}.py'
best_model_path = f'runs/mmdetection/{exp_name}/train/'
exp_id = max([f for f in os.listdir(best_model_path) if os.path.isdir(os.path.join(best_model_path, f))])  # 最新实验
files = glob.glob(f'{best_model_path}/best_coco_bbox_mAP_epoch_*.pth')  # TODO: 按epoch数排序
best_model_path = files[0] if files else None
train_log_path = f'runs/mmdetection/{exp_name}/train/{exp_id}/vis_data/scalars.json'

print(f'{exp_name=}')
print(f'{best_model_path=}')
print(f'{train_log_path=}')
# Out:
# exp_name='faster_rcnn_1333'
# best_model_path='runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth'
# train_log_path='runs/mmdetection/faster_rcnn_1333/train/20231121_195808/vis_data/scalars.json'

# %% [markdown]
# # 日志分析

# %%
from src.utils.read import read_mmdet_train_log_json
from src.utils.plot import plot_mmdet_fastern_rcnn_train_log

df_train, df_val = read_mmdet_train_log_json(train_log_path)
plot_mmdet_fastern_rcnn_train_log(df_train, df_val, exp_name=exp_name)
# Out:
# ['lr', 'data_time', 'loss', 'loss_rpn_cls', 'loss_rpn_bbox', 'loss_cls', 'acc', 'loss_bbox', 'time', 'iter', 'memory', 'step']
# ['coco/bbox_mAP', 'coco/bbox_mAP_50', 'coco/bbox_mAP_75', 'coco/bbox_mAP_s', 'coco/bbox_mAP_m', 'coco/bbox_mAP_l', 'data_time', 'time']
# 最大map: (139)0.937

# %% [markdown]
# # 测试

# %%
! scripts/mmdet_test.sh {cfg_path} {best_model_path} {exp_name} {gpu_id}
# Out:
# 06/02 22:28:48 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:23:11) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu118
#     OpenCV: 4.9.0
#     MMEngine: 0.10.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 0
#     diff_rank_seed: True
#     deterministic: True
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/02 22:28:48 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=True)
# batch_size = dict(test=2, train=2, val=2)
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         122.00711516,
#         141.11828193,
#         164.56574534,
#     ],
#     pad_size_divisor=32,
#     std=[
#         46.91310377,
#         54.8164231,
#         70.38650678,
#     ],
#     type='DetDataPreprocessor')
# data_root = 'datasets/lard/'
# dataset_type = 'LardDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1, max_keep_ckpts=1, save_best='auto', type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.005,
#         monitor='coco/bbox_mAP',
#         patience=50,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=25, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# exp_name = 'faster_rcnn_1333'
# img_size = 1333
# input_size = (
#     1333,
#     800,
# )
# launcher = 'none'
# load_from = 'runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             122.00711516,
#             141.11828193,
#             164.56574534,
#         ],
#         pad_size_divisor=32,
#         std=[
#             46.91310377,
#             54.8164231,
#             70.38650678,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#             loss_cls=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             num_classes=1,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead'),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='StandardRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=8,
#             nms=dict(iou_threshold=0.6, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=False,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_pos_ub=-1,
#                 num=512,
#                 pos_fraction=0.25,
#                 type='RandomSampler')),
#         rpn=dict(
#             allowed_border=-1,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='FasterRCNN')
# model_cfg = ''
# model_name = 'faster_rcnn'
# model_stru = ''
# num_epochs = 500
# num_workers = 8
# optim_wrapper = dict(
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(begin=0, by_epoch=True, end=3, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=3,
#         by_epoch=True,
#         end=500,
#         gamma=0.1,
#         milestones=[
#             350,
#             400,
#         ],
#         type='MultiStepLR'),
# ]
# randomness = dict(deterministic=True, diff_rank_seed=True, seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='annotations/instances_test_synth.json',
#         backend_args=None,
#         data_prefix=dict(img='detection/test_synth/images/'),
#         data_root='datasets/lard/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='LardDataset'),
#     drop_last=False,
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='datasets/lard/annotations/instances_test_synth.json',
#     backend_args=None,
#     format_only=True,
#     metric='bbox',
#     outfile_prefix=
#     'runs/mmdetection/faster_rcnn_1333/test/coco_detection/prediction_test_synth',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         dataset=dict(
#             ann_file='annotations/instances_train.json',
#             backend_args=None,
#             data_prefix=dict(img='detection/train/images/'),
#             data_root='datasets/lard/',
#             filter_cfg=dict(filter_empty_gt=True, min_size=0),
#             pipeline=[
#                 dict(backend_args=None, type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations', with_bbox=True),
#                 dict(keep_ratio=True, scale=(
#                     1333,
#                     800,
#                 ), type='Resize'),
#                 dict(prob=0.5, type='RandomFlip'),
#                 dict(type='PackDetInputs'),
#             ],
#             type='LardDataset'),
#         times=1,
#         type='RepeatDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='annotations/instances_val.json',
#         backend_args=None,
#         data_prefix=dict(img='detection/val/images/'),
#         data_root='datasets/lard/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='LardDataset'),
#     drop_last=False,
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='datasets/lard/annotations/instances_val.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = 'runs/mmdetection/faster_rcnn_1333/test'
#
# 06/02 22:28:50 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/02 22:28:50 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 06/02 22:28:50 - mmengine - WARNING - The prefix is not set in metric class DumpDetResults.
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Loads checkpoint by local backend from path: runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth
# 06/02 22:28:51 - mmengine - INFO - Load checkpoint from runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth
# 06/02 22:28:53 - mmengine - INFO - Epoch(test) [  25/1106]    eta: 0:01:29  time: 0.0828  data_time: 0.0127  memory: 702
# 06/02 22:28:54 - mmengine - INFO - Epoch(test) [  50/1106]    eta: 0:01:13  time: 0.0692  data_time: 0.0081  memory: 702
# 06/02 22:28:55 - mmengine - INFO - Epoch(test) [  75/1106]    eta: 0:01:06  time: 0.0552  data_time: 0.0035  memory: 702
# 06/02 22:28:57 - mmengine - INFO - Epoch(test) [ 100/1106]    eta: 0:01:02  time: 0.0547  data_time: 0.0035  memory: 702
# 06/02 22:29:31 - mmengine - INFO - Epoch(test) [ 700/1106]    eta: 0:00:23  time: 0.0607  data_time: 0.0049  memory: 702
# 06/02 22:29:32 - mmengine - INFO - Epoch(test) [ 725/1106]    eta: 0:00:21  time: 0.0586  data_time: 0.0043  memory: 702
# 06/02 22:29:33 - mmengine - INFO - Epoch(test) [ 750/1106]    eta: 0:00:20  time: 0.0556  data_time: 0.0035  memory: 702
# 06/02 22:29:35 - mmengine - INFO - Epoch(test) [ 775/1106]    eta: 0:00:18  time: 0.0549  data_time: 0.0033  memory: 702
# 06/02 22:29:36 - mmengine - INFO - Epoch(test) [ 800/1106]    eta: 0:00:17  time: 0.0551  data_time: 0.0034  memory: 702
# 06/02 22:29:38 - mmengine - INFO - Epoch(test) [ 825/1106]    eta: 0:00:15  time: 0.0548  data_time: 0.0033  memory: 702
# 06/02 22:29:39 - mmengine - INFO - Epoch(test) [ 850/1106]    eta: 0:00:14  time: 0.0546  data_time: 0.0032  memory: 702
# 06/02 22:29:40 - mmengine - INFO - Epoch(test) [ 875/1106]    eta: 0:00:13  time: 0.0545  data_time: 0.0031  memory: 702
# 06/02 22:29:42 - mmengine - INFO - Epoch(test) [ 900/1106]    eta: 0:00:11  time: 0.0544  data_time: 0.0031  memory: 702
# 06/02 22:29:43 - mmengine - INFO - Epoch(test) [ 925/1106]    eta: 0:00:10  time: 0.0544  data_time: 0.0031  memory: 702
# 06/02 22:29:44 - mmengine - INFO - Epoch(test) [ 950/1106]    eta: 0:00:08  time: 0.0546  data_time: 0.0031  memory: 702
# 06/02 22:29:46 - mmengine - INFO - Epoch(test) [ 975/1106]    eta: 0:00:07  time: 0.0547  data_time: 0.0031  memory: 702
# 06/02 22:29:47 - mmengine - INFO - Epoch(test) [1000/1106]    eta: 0:00:05  time: 0.0546  data_time: 0.0032  memory: 702
# 06/02 22:29:48 - mmengine - INFO - Epoch(test) [1025/1106]    eta: 0:00:04  time: 0.0546  data_time: 0.0032  memory: 702
# 06/02 22:29:50 - mmengine - INFO - Epoch(test) [1050/1106]    eta: 0:00:03  time: 0.0546  data_time: 0.0031  memory: 702
# 06/02 22:29:51 - mmengine - INFO - Epoch(test) [1075/1106]    eta: 0:00:01  time: 0.0546  data_time: 0.0031  memory: 702
# 06/02 22:29:53 - mmengine - INFO - Epoch(test) [1100/1106]    eta: 0:00:00  time: 0.0546  data_time: 0.0031  memory: 702
# 06/02 22:29:53 - mmengine - INFO - results are saved in runs/mmdetection/faster_rcnn_1333/test/coco_detection
# 06/02 22:29:53 - mmengine - INFO - Results has been saved to runs/mmdetection/faster_rcnn_1333/test/coco_detection/prediction_test_synth.pkl.
# 06/02 22:29:53 - mmengine - INFO - Epoch(test) [1106/1106]    data_time: 0.0038  time: 0.0562
# 06/02 22:29:58 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:23:11) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu118
#     OpenCV: 4.9.0
#     MMEngine: 0.10.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 0
#     diff_rank_seed: True
#     deterministic: True
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/02 22:29:58 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=True)
# batch_size = dict(test=2, train=2, val=2)
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         122.00711516,
#         141.11828193,
#         164.56574534,
#     ],
#     pad_size_divisor=32,
#     std=[
#         46.91310377,
#         54.8164231,
#         70.38650678,
#     ],
#     type='DetDataPreprocessor')
# data_root = 'datasets/lard/'
# dataset_type = 'LardDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1, max_keep_ckpts=1, save_best='auto', type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.005,
#         monitor='coco/bbox_mAP',
#         patience=50,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=25, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# exp_name = 'faster_rcnn_1333'
# img_size = 1333
# input_size = (
#     1333,
#     800,
# )
# launcher = 'none'
# load_from = 'runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             122.00711516,
#             141.11828193,
#             164.56574534,
#         ],
#         pad_size_divisor=32,
#         std=[
#             46.91310377,
#             54.8164231,
#             70.38650678,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#             loss_cls=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             num_classes=1,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead'),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='StandardRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=8,
#             nms=dict(iou_threshold=0.6, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=False,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_pos_ub=-1,
#                 num=512,
#                 pos_fraction=0.25,
#                 type='RandomSampler')),
#         rpn=dict(
#             allowed_border=-1,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='FasterRCNN')
# model_cfg = ''
# model_name = 'faster_rcnn'
# model_stru = ''
# num_epochs = 500
# num_workers = 8
# optim_wrapper = dict(
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(begin=0, by_epoch=True, end=3, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=3,
#         by_epoch=True,
#         end
time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:33:59 - mmengine - INFO - Epoch(test) [1425/2012]    eta: 0:00:34  time: 0.0661  data_time: 0.0034  memory: 875
# 06/02 22:34:00 - mmengine - INFO - Epoch(test) [1450/2012]    eta: 0:00:33  time: 0.0661  data_time: 0.0035  memory: 875
# 06/02 22:34:02 - mmengine - INFO - Epoch(test) [1475/2012]    eta: 0:00:31  time: 0.0662  data_time: 0.0035  memory: 875
# 06/02 22:34:03 - mmengine - INFO - Epoch(test) [1500/2012]    eta: 0:00:30  time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:34:05 - mmengine - INFO - Epoch(test) [1525/2012]    eta: 0:00:28  time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:34:07 - mmengine - INFO - Epoch(test) [1550/2012]    eta: 0:00:27  time: 0.0664  data_time: 0.0035  memory: 875
# 06/02 22:34:08 - mmengine - INFO - Epoch(test) [1575/2012]    eta: 0:00:26  time: 0.0664  data_time: 0.0035  memory: 875
# 06/02 22:34:10 - mmengine - INFO - Epoch(test) [1600/2012]    eta: 0:00:24  time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:34:12 - mmengine - INFO - Epoch(test) [1625/2012]    eta: 0:00:23  time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:34:13 - mmengine - INFO - Epoch(test) [1650/2012]    eta: 0:00:21  time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:34:15 - mmengine - INFO - Epoch(test) [1675/2012]    eta: 0:00:20  time: 0.0662  data_time: 0.0034  memory: 875
# 06/02 22:34:17 - mmengine - INFO - Epoch(test) [1700/2012]    eta: 0:00:18  time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:34:18 - mmengine - INFO - Epoch(test) [1725/2012]    eta: 0:00:17  time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:34:20 - mmengine - INFO - Epoch(test) [1750/2012]    eta: 0:00:15  time: 0.0664  data_time: 0.0036  memory: 875
# 06/02 22:34:22 - mmengine - INFO - Epoch(test) [1775/2012]    eta: 0:00:14  time: 0.0663  data_time: 0.0035  memory: 875
# 06/02 22:34:23 - mmengine - INFO - Epoch(test) [1800/2012]    eta: 0:00:12  time: 0.0661  data_time: 0.0034  memory: 875
# 06/02 22:34:25 - mmengine - INFO - Epoch(test) [1825/2012]    eta: 0:00:11  time: 0.0661  data_time: 0.0034  memory: 875
# 06/02 22:34:27 - mmengine - INFO - Epoch(test) [1850/2012]    eta: 0:00:09  time: 0.0662  data_time: 0.0035  memory: 875
# 06/02 22:34:28 - mmengine - INFO - Epoch(test) [1875/2012]    eta: 0:00:08  time: 0.0662  data_time: 0.0035  memory: 875
# 06/02 22:34:30 - mmengine - INFO - Epoch(test) [1900/2012]    eta: 0:00:06  time: 0.0661  data_time: 0.0036  memory: 875
# 06/02 22:34:32 - mmengine - INFO - Epoch(test) [1925/2012]    eta: 0:00:05  time: 0.0661  data_time: 0.0036  memory: 875
# 06/02 22:34:33 - mmengine - INFO - Epoch(test) [1950/2012]    eta: 0:00:03  time: 0.0660  data_time: 0.0035  memory: 875
# 06/02 22:34:35 - mmengine - INFO - Epoch(test) [1975/2012]    eta: 0:00:02  time: 0.0658  data_time: 0.0035  memory: 875
# 06/02 22:34:37 - mmengine - INFO - Epoch(test) [2000/2012]    eta: 0:00:00  time: 0.0657  data_time: 0.0034  memory: 875
# 06/02 22:34:38 - mmengine - INFO - results are saved in runs/mmdetection/faster_rcnn_1333/test/coco_detection
# 06/02 22:34:38 - mmengine - INFO - Results has been saved to runs/mmdetection/faster_rcnn_1333/test/coco_detection/prediction_test.pkl.
# 06/02 22:34:38 - mmengine - INFO - Epoch(test) [2012/2012]    data_time: 0.0037  time: 0.0612

# %% [markdown]
# # 评估

# %%
# 提供两种测试评价方案，结果一致
# 方式1: pycocotools
import pandas as pd
from src.utils.metric import coco_metrics_name
from src.utils.metric import cal_coco_metrics

# 保存评价结果对象
coco_evals = {}
# 构造dataframe
all_metrics = {}

# 在各测试集进行推理
for data_type in ['test_synth', 'test_real_nominal', 'test_real_edge', 'test_real', 'test']:

    print(f'正在评价: {data_type}')
    annotation_file = f'datasets/lard/annotations/instances_{data_type}.json'
    prediction_file = f'runs/mmdetection/{exp_name}/test/coco_detection/prediction_{data_type}.bbox.json'
    cocoEval = cal_coco_metrics(annotation_file, prediction_file)
    coco_evals[data_type] = cocoEval
    all_metrics[data_type] = cocoEval.stats

all_metrics = pd.DataFrame(all_metrics, index=coco_metrics_name)
display(all_metrics.round(3))


# 方式2: eval_metric.py
# ! python 3rdparty/mmdetection/tools/analysis_tools/eval_metric.py \
#     {cfg_path} \
#     runs/mmdetection/{exp_name}/test/coco_detection/prediction_test_synth.pkl \
#     --cfg-options \
#     test_evaluator.format_only=False
# Out:
# 正在评价: test_synth
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.64s).
# Accumulating evaluation results...
# DONE (t=0.14s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.719
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.851
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.612
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.766
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.660
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.822
# 正在评价: test_real_nominal
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.47s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.747
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.784
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.610
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.610
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.506
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.823
# 正在评价: test_real_edge
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.308
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.444
# 正在评价: test_real
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.78s).
# Accumulating evaluation results...
# DONE (t=0.09s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.696
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.604
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.430
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.702
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.746
# 正在评价: test
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.95s).
# Accumulating evaluation results...
# DONE (t=0.18s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.847
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.740
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.125
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.521
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.668
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
#                                               test_synth  test_real_nominal  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)          0.719              0.566
# AP (IoU=0.50, area=all, maxDets=100)               0.958              0.747
# AP (IoU=0.75, area=all, maxDets=100)               0.851              0.666
# AP (IoU=0.50:0.95, area=small, maxDets=100)       -1.000              0.127
# AP (IoU=0.50:0.95, area=medium, maxDets=100)       0.612              0.471
# AP (IoU=0.50:0.95, area=large, maxDets=100)        0.770              0.784
# AR (IoU=0.50:0.95, area=all, maxDets=1)            0.766              0.595
# AR (IoU=0.50:0.95, area=all, maxDets=10)           0.767              0.610
# AR (IoU=0.50:0.95, area=all, maxDets=100)          0.767              0.610
# AR (IoU=0.50:0.95, area=small, maxDets=100)       -1.000              0.135
# AR (IoU=0.50:0.95, area=medium, maxDets=100)       0.660              0.506
# AR (IoU=0.50:0.95, area=large, maxDets=100)        0.822              0.823
#
#                                               test_real_edge  test_real   test
# AP (IoU=0.50:0.95, area=all, maxDets=100)              0.286      0.517  0.630
# AP (IoU=0.50, area=all, maxDets=100)                   0.449      0.696  0.847
# AP (IoU=0.75, area=all, maxDets=100)                   0.308      0.604  0.740
# AP (IoU=0.50:0.95, area=small, maxDets=100)            0.113      0.126  0.125
# AP (IoU=0.50:0.95, area=medium, maxDets=100)           0.206      0.430  0.521
# AP (IoU=0.50:0.95, area=large, maxDets=100)            0.379      0.702  0.743
# AR (IoU=0.50:0.95, area=all, maxDets=1)                0.322      0.548  0.668
# AR (IoU=0.50:0.95, area=all, maxDets=10)               0.336      0.563  0.675
# AR (IoU=0.50:0.95, area=all, maxDets=100)              0.336      0.563  0.675
# AR (IoU=0.50:0.95, area=small, maxDets=100)            0.120      0.133  0.133
# AR (IoU=0.50:0.95, area=medium, maxDets=100)           0.221      0.465  0.562
# AR (IoU=0.50:0.95, area=large, maxDets=100)            0.444      0.746  0.794

# %%
# from src.utils.plot import plot_pr_curve

# plot_pr_curve(coco_evals, iou_indices=[0, 2, 4, 6, 8], exp_name=exp_name)

# %% [markdown]
# # 参数量

# %%
# ! scripts/mmdet_flops.sh {cfg_path}

import argparse
import importlib
import pandas as pd
from mmengine.logging import MMLogger
module = importlib.import_module("3rdparty.mmdetection.tools.analysis_tools.get_flops")
inference = module.inference

args = argparse.Namespace(
    config=cfg_path,
    num_images=1,
    cfg_options=dict()
)
logger = MMLogger.get_instance(name='MMLogger')
result = inference(args, logger)
split_line = '=' * 30
ori_shape = result['ori_shape']
pad_shape = result['pad_shape']
flops = result['flops']
params = result['params']
compute_type = result['compute_type']

if pad_shape != ori_shape:
    print(f'{split_line}\nUse size divisor set input shape '
            f'from {ori_shape} to {pad_shape}')
print(f'{split_line}\nCompute type: {compute_type}\n'
        f'Input shape: {pad_shape}\nFlops: {flops}\n'
        f'Params: {params}\n{split_line}')

# 数据重构
all_complex = {}
for data_type in ['test_synth', 'test_real_nominal', 'test_real_edge', 'test_real', 'test']:
    all_complex[data_type] = [params, flops]  # 仅为便于数据拼接
all_complex = pd.DataFrame(
    data=all_complex,
    index=['Param', 'FLOPs']
)

# 合并复杂度指标
all_metrics = pd.concat([all_metrics, all_complex], axis=0)
all_metrics
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 06/02 22:35:41 - mmengine - WARNING - Unsupported operator aten::add_ encountered 19 time(s)
# 06/02 22:35:41 - mmengine - WARNING - Unsupported operator aten::add encountered 18 time(s)
# 06/02 22:35:41 - mmengine - WARNING - Unsupported operator aten::mul encountered 21 time(s)
# 06/02 22:35:41 - mmengine - WARNING - Unsupported operator prim::PythonOp.RoIAlignFunction encountered 1 time(s)
# 06/02 22:35:41 - mmengine - WARNING - Unsupported operator aten::sum encountered 3 time(s)
# 06/02 22:35:41 - mmengine - WARNING - The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# data_preprocessor, roi_head.bbox_head.loss_bbox, roi_head.bbox_head.loss_cls, roi_head.bbox_roi_extractor.roi_layers.1, roi_head.bbox_roi_extractor.roi_layers.2, roi_head.bbox_roi_extractor.roi_layers.3, rpn_head.loss_bbox, rpn_head.loss_cls
# ==============================
# Use size divisor set input shape from (2048, 2448) to (800, 960)
# ==============================
# Compute type: dataloader: load a picture from the dataset
# Input shape: (800, 960)
# Flops: 158.27570048
# Params: 41.348181
# ==============================
#                                               test_synth  test_real_nominal  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)       0.719416           0.565510
# AP (IoU=0.50, area=all, maxDets=100)            0.957715           0.747188
# AP (IoU=0.75, area=all, maxDets=100)            0.850715           0.666032
# AP (IoU=0.50:0.95, area=small, maxDets=100)    -1.000000           0.126534
# AP (IoU=0.50:0.95, area=medium, maxDets=100)    0.612358           0.470891
# AP (IoU=0.50:0.95, area=large, maxDets=100)     0.769647           0.783591
# AR (IoU=0.50:0.95, area=all, maxDets=1)         0.766275           0.594933
# AR (IoU=0.50:0.95, area=all, maxDets=10)        0.767269           0.609600
# AR (IoU=0.50:0.95, area=all, maxDets=100)       0.767269           0.609600
# AR (IoU=0.50:0.95, area=small, maxDets=100)    -1.000000           0.135119
# AR (IoU=0.50:0.95, area=medium, maxDets=100)    0.659786           0.505590
# AR (IoU=0.50:0.95, area=large, maxDets=100)     0.821965           0.822820
# Param                                          41.348181          41.348181
# FLOPs                                         158.275700         158.275700
#
#                                               test_real_edge   test_real  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)           0.285985    0.517273
# AP (IoU=0.50, area=all, maxDets=100)                0.449437    0.695557
# AP (IoU=0.75, area=all, maxDets=100)                0.307835    0.603615
# AP (IoU=0.50:0.95, area=small, maxDets=100)         0.112532    0.125912
# AP (IoU=0.50:0.95, area=medium, maxDets=100)        0.205716    0.430275
# AP (IoU=0.50:0.95, area=large, maxDets=100)         0.379040    0.702217
# AR (IoU=0.50:0.95, area=all, maxDets=1)             0.321865    0.548040
# AR (IoU=0.50:0.95, area=all, maxDets=10)            0.336013    0.562617
# AR (IoU=0.50:0.95, area=all, maxDets=100)           0.336013    0.562617
# AR (IoU=0.50:0.95, area=small, maxDets=100)         0.120000    0.132828
# AR (IoU=0.50:0.95, area=medium, maxDets=100)        0.221495    0.465113
# AR (IoU=0.50:0.95, area=large, maxDets=100)         0.443678    0.746288
# Param                                              41.348181   41.348181
# FLOPs                                             158.275700  158.275700
#
#                                                     test
# AP (IoU=0.50:0.95, area=all, maxDets=100)       0.630163
# AP (IoU=0.50, area=all, maxDets=100)            0.847076
# AP (IoU=0.75, area=all, maxDets=100)            0.739861
# AP (IoU=0.50:0.95, area=small, maxDets=100)     0.124876
# AP (IoU=0.50:0.95, area=medium, maxDets=100)    0.521251
# AP (IoU=0.50:0.95, area=large, maxDets=100)     0.743253
# AR (IoU=0.50:0.95, area=all, maxDets=1)         0.668258
# AR (IoU=0.50:0.95, area=all, maxDets=10)        0.675367
# AR (IoU=0.50:0.95, area=all, maxDets=100)       0.675367
# AR (IoU=0.50:0.95, area=small, maxDets=100)     0.132828
# AR (IoU=0.50:0.95, area=medium, maxDets=100)    0.562124
# AR (IoU=0.50:0.95, area=large, maxDets=100)     0.794330
# Param                                          41.348181
# FLOPs                                         158.275700

# %% [markdown]
# # 测速

# %%
! scripts/mmdet_speed.sh {cfg_path} {best_model_path} {gpu_id}
# Out:
# 06/02 22:35:49 - mmengine - INFO - before build:
# 06/02 22:35:49 - mmengine - INFO - (GB) mem_used: 5.52 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 06/02 22:35:50 - mmengine - INFO - after build:
# 06/02 22:35:50 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.59 | pss: 0.71 | total_proc: 1
# 06/02 22:36:27 - mmengine - INFO - ==================================
# 06/02 22:36:28 - mmengine - INFO - Done image [500/2000], fps: 35.2 img/s, times per image: 28.4 ms/img, cuda memory: 449 MB
# 06/02 22:36:28 - mmengine - INFO - (GB) mem_used: 6.02 | uss: 0.81 | pss: 0.98 | total_proc: 1
# 06/02 22:37:04 - mmengine - INFO - ==================================
# 06/02 22:37:04 - mmengine - INFO - Done image [1000/2000], fps: 35.2 img/s, times per image: 28.4 ms/img, cuda memory: 449 MB
# 06/02 22:37:04 - mmengine - INFO - (GB) mem_used: 6.02 | uss: 0.81 | pss: 0.98 | total_proc: 1
# 06/02 22:37:41 - mmengine - INFO - ==================================
# 06/02 22:37:41 - mmengine - INFO - Done image [1500/2000], fps: 35.2 img/s, times per image: 28.4 ms/img, cuda memory: 449 MB
# 06/02 22:37:41 - mmengine - INFO - (GB) mem_used: 6.01 | uss: 0.81 | pss: 0.98 | total_proc: 1
# 06/02 22:38:18 - mmengine - INFO - ==================================
# 06/02 22:38:18 - mmengine - INFO - Done image [2000/2000], fps: 35.2 img/s, times per image: 28.4 ms/img, cuda memory: 449 MB
# 06/02 22:38:18 - mmengine - INFO - (GB) mem_used: 6.00 | uss: 0.81 | pss: 0.98 | total_proc: 1
# 06/02 22:38:18 - mmengine - INFO - ============== Done ==================
# 06/02 22:38:18 - mmengine - INFO - Overall fps: 35.2 img/s, times per image: 28.4 ms/img
# 06/02 22:38:18 - mmengine - INFO - cuda memory: 193 MB
# 06/02 22:38:18 - mmengine - INFO - (GB) mem_used: 5.97 | uss: 0.77 | pss: 0.95 | total_proc: 1
# 06/02 22:38:22 - mmengine - INFO - before build:
# 06/02 22:38:22 - mmengine - INFO - (GB) mem_used: 5.50 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/02 22:38:23 - mmengine - INFO - after build:
# 06/02 22:38:23 - mmengine - INFO - (GB) mem_used: 5.79 | uss: 0.59 | pss: 0.71 | total_proc: 1
# 06/02 22:39:19 - mmengine - INFO - ==================================
# 06/02 22:39:19 - mmengine - INFO - Done image [500/2000], fps: 31.0 img/s, times per image: 32.3 ms/img, cuda memory: 537 MB
# 06/02 22:39:19 - mmengine - INFO - (GB) mem_used: 5.98 | uss: 0.80 | pss: 0.97 | total_proc: 1
# 06/02 22:40:14 - mmengine - INFO - ==================================
# 06/02 22:40:14 - mmengine - INFO - Done image [1000/2000], fps: 31.0 img/s, times per image: 32.3 ms/img, cuda memory: 537 MB
# 06/02 22:40:14 - mmengine - INFO - (GB) mem_used: 5.97 | uss: 0.80 | pss: 0.97 | total_proc: 1
# 06/02 22:41:08 - mmengine - INFO - ==================================
# 06/02 22:41:08 - mmengine - INFO - Done image [1500/2000], fps: 31.0 img/s, times per image: 32.2 ms/img, cuda memory: 537 MB
# 06/02 22:41:08 - mmengine - INFO - (GB) mem_used: 5.97 | uss: 0.79 | pss: 0.96 | total_proc: 1
# 06/02 22:41:08 - mmengine - INFO - ============== Done ==================
# 06/02 22:41:08 - mmengine - INFO - Overall fps: 31.0 img/s, times per image: 32.3 ms/img
# 06/02 22:41:08 - mmengine - INFO - cuda memory: 193 MB
# 06/02 22:41:08 - mmengine - INFO - (GB) mem_used: 5.97 | uss: 0.79 | pss: 0.96 | total_proc: 1
# 06/02 22:41:12 - mmengine - INFO - before build:
# 06/02 22:41:12 - mmengine - INFO - (GB) mem_used: 5.50 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/02 22:41:13 - mmengine - INFO - after build:
# 06/02 22:41:13 - mmengine - INFO - (GB) mem_used: 5.78 | uss: 0.59 | pss: 0.71 | total_proc: 1
# 06/02 22:41:24 - mmengine - INFO - ==================================
# 06/02 22:41:35 - mmengine - INFO - ==================================
# 06/02 22:41:35 - mmengine - INFO - Done image [200/2000], fps: 30.8 img/s, times per image: 32.5 ms/img, cuda memory: 537 MB
# 06/02 22:41:35 - mmengine - INFO - (GB) mem_used: 6.01 | uss: 0.83 | pss: 1.00 | total_proc: 1
# 06/02 22:41:46 - mmengine - INFO - ==================================
# 06/02 22:41:46 - mmengine - INFO - Done image [300/2000], fps: 31.0 img/s, times per image: 32.3 ms/img, cuda memory: 537 MB
# 06/02 22:41:46 - mmengine - INFO - (GB) mem_used: 6.01 | uss: 0.83 | pss: 1.00 | total_proc: 1
# 06/02 22:41:47 - mmengine - INFO - ============== Done ==================
# 06/02 22:41:47 - mmengine - INFO - Overall fps: 31.0 img/s, times per image: 32.3 ms/img
# 06/02 22:41:47 - mmengine - INFO - cuda memory: 537 MB
# 06/02 22:41:47 - mmengine - INFO - (GB) mem_used: 5.97 | uss: 0.79 | pss: 0.96 | total_proc: 1
# 06/02 22:41:50 - mmengine - INFO - before build:
# 06/02 22:41:50 - mmengine - INFO - (GB) mem_used: 5.49 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/02 22:41:51 - mmengine - INFO - after build:
# 06/02 22:41:51 - mmengine - INFO - (GB) mem_used: 5.78 | uss: 0.59 | pss: 0.71 | total_proc: 1
# 06/02 22:42:47 - mmengine - INFO - ==================================
# 06/02 22:42:47 - mmengine - INFO - Done image [500/2000], fps: 30.8 img/s, times per image: 32.5 ms/img, cuda memory: 537 MB
# 06/02 22:42:47 - mmengine - INFO - (GB) mem_used: 5.98 | uss: 0.80 | pss: 0.97 | total_proc: 1
# 06/02 22:43:43 - mmengine - INFO - ==================================
# 06/02 22:43:43 - mmengine - INFO - Done image [1000/2000], fps: 30.9 img/s, times per image: 32.4 ms/img, cuda memory: 537 MB
# 06/02 22:43:43 - mmengine - INFO - (GB) mem_used: 5.98 | uss: 0.80 | pss: 0.97 | total_proc: 1
# 06/02 22:44:37 - mmengine - INFO - ==================================
# 06/02 22:44:37 - mmengine - INFO - Done image [1500/2000], fps: 31.0 img/s, times per image: 32.3 ms/img, cuda memory: 537 MB
# 06/02 22:44:37 - mmengine - INFO - (GB) mem_used: 5.97 | uss: 0.79 | pss: 0.96 | total_proc: 1
# 06/02 22:45:11 - mmengine - INFO - ============== Done ==================
# 06/02 22:45:11 - mmengine - INFO - Overall fps: 31.0 img/s, times per image: 32.3 ms/img
# 06/02 22:45:11 - mmengine - INFO - cuda memory: 537 MB
# 06/02 22:45:11 - mmengine - INFO - (GB) mem_used: 5.97 | uss: 0.79 | pss: 0.96 | total_proc: 1
# 06/02 22:45:15 - mmengine - INFO - before build:
# 06/02 22:45:15 - mmengine - INFO - (GB) mem_used: 5.50 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/faster_rcnn_1333/train/best_coco_bbox_mAP_epoch_139.pth
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 06/02 22:45:16 - mmengine - INFO - after build:
# 06/02 22:45:17 - mmengine - INFO - (GB) mem_used: 5.80 | uss: 0.59 | pss: 0.71 | total_proc: 1
# 06/02 22:45:54 - mmengine - INFO - ==================================
# 06/02 22:45:54 - mmengine - INFO - Done image [500/2000], fps: 35.5 img/s, times per image: 28.2 ms/img, cuda memory: 449 MB
# 06/02 22:45:54 - mmengine - INFO - (GB) mem_used: 6.00 | uss: 0.81 | pss: 0.98 | total_proc: 1
# 06/02 22:46:30 - mmengine - INFO - ==================================
# 06/02 22:46:30 - mmengine - INFO - Done image [1000/2000], fps: 35.4 img/s, times per image: 28.2 ms/img, cuda memory: 449 MB
# 06/02 22:46:31 - mmengine - INFO - (GB) mem_used: 6.00 | uss: 0.81 | pss: 0.98 | total_proc: 1
# 06/02 22:47:07 - mmengine - INFO - ==================================
# 06/02 22:47:07 - mmengine - INFO - Done image [1500/2000], fps: 35.4 img/s, times per image: 28.2 ms/img, cuda memory: 449 MB
# 06/02 22:47:07 - mmengine - INFO - (GB) mem_used: 6.00 | uss: 0.81 | pss: 0.98 | total_proc: 1
# 06/02 22:47:44 - mmengine - INFO - ==================================
# 06/02 22:47:44 - mmengine - INFO - Done image [2000/2000], fps: 35.4 img/s, times per image: 28.2 ms/img, cuda memory: 449 MB
# 06/02 22:47:44 - mmengine - INFO - (GB) mem_used: 6.00 | uss: 0.81 | pss: 0.98 | total_proc: 1
# 06/02 22:47:44 - mmengine - INFO - ============== Done ==================
# 06/02 22:47:44 - mmengine - INFO - Overall fps: 35.4 img/s, times per image: 28.2 ms/img
# 06/02 22:47:44 - mmengine - INFO - cuda memory: 193 MB
# 06/02 22:47:44 - mmengine - INFO - (GB) mem_used: 6.00 | uss: 0.81 | pss: 0.98 | total_proc: 1

# %%
# 06/02 22:38:18 - mmengine - INFO - ============== Done ==================
# 06/02 22:38:18 - mmengine - INFO - Overall fps: 35.2 img/s, times per image: 28.4 ms/img

# 06/02 22:41:08 - mmengine - INFO - ============== Done ==================
# 06/02 22:41:08 - mmengine - INFO - Overall fps: 31.0 img/s, times per image: 32.3 ms/img

# 06/02 22:41:47 - mmengine - INFO - ============== Done ==================
# 06/02 22:41:47 - mmengine - INFO - Overall fps: 31.0 img/s, times per image: 32.3 ms/img

# 06/02 22:45:11 - mmengine - INFO - ============== Done ==================
# 06/02 22:45:11 - mmengine - INFO - Overall fps: 31.0 img/s, times per image: 32.3 ms/img

# 06/02 22:47:44 - mmengine - INFO - ============== Done ==================
# 06/02 22:47:44 - mmengine - INFO - Overall fps: 35.4 img/s, times per image: 28.2 ms/img

# %%
# 保存结果
all_speed = {
    'test_synth': [28.4, 35.2],  # [average_time, fps]
    'test_real_nominal': [32.3, 31.0],
    'test_real_edge': [32.3, 31.0],
    'test_real': [32.3, 31.0],
    'test': [28.2, 35.4]
}

# 构建dataframe
all_speed = pd.DataFrame(
    data=all_speed,
    index=['Time', 'FPS']
)

# 合并测试指标
all_metrics = pd.concat([all_metrics, all_speed], axis=0)
all_metrics
# Out:
#                                               test_synth  test_real_nominal  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)       0.719416           0.565510
# AP (IoU=0.50, area=all, maxDets=100)            0.957715           0.747188
# AP (IoU=0.75, area=all, maxDets=100)            0.850715           0.666032
# AP (IoU=0.50:0.95, area=small, maxDets=100)    -1.000000           0.126534
# AP (IoU=0.50:0.95, area=medium, maxDets=100)    0.612358           0.470891
# AP (IoU=0.50:0.95, area=large, maxDets=100)     0.769647           0.783591
# AR (IoU=0.50:0.95, area=all, maxDets=1)         0.766275           0.594933
# AR (IoU=0.50:0.95, area=all, maxDets=10)        0.767269           0.609600
# AR (IoU=0.50:0.95, area=all, maxDets=100)       0.767269           0.609600
# AR (IoU=0.50:0.95, area=small, maxDets=100)    -1.000000           0.135119
# AR (IoU=0.50:0.95, area=medium, maxDets=100)    0.659786           0.505590
# AR (IoU=0.50:0.95, area=large, maxDets=100)     0.821965           0.822820
# Param                                          41.348181          41.348181
# FLOPs                                         158.275700         158.275700
# Time                                           28.400000          32.300000
# FPS                                            35.200000          31.000000
#
#                                               test_real_edge   test_real  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)           0.285985    0.517273
# AP (IoU=0.50, area=all, maxDets=100)                0.449437    0.695557
# AP (IoU=0.75, area=all, maxDets=100)                0.307835    0.603615
# AP (IoU=0.50:0.95, area=small, maxDets=100)         0.112532    0.125912
# AP (IoU=0.50:0.95, area=medium, maxDets=100)        0.205716    0.430275
# AP (IoU=0.50:0.95, area=large, maxDets=100)         0.379040    0.702217
# AR (IoU=0.50:0.95, area=all, maxDets=1)             0.321865    0.548040
# AR (IoU=0.50:0.95, area=all, maxDets=10)            0.336013    0.562617
# AR (IoU=0.50:0.95, area=all, maxDets=100)           0.336013    0.562617
# AR (IoU=0.50:0.95, area=small, maxDets=100)         0.120000    0.132828
# AR (IoU=0.50:0.95, area=medium, maxDets=100)        0.221495    0.465113
# AR (IoU=0.50:0.95, area=large, maxDets=100)         0.443678    0.746288
# Param                                              41.348181   41.348181
# FLOPs                                             158.275700  158.275700
# Time                                               32.300000   32.300000
# FPS                                                31.000000   31.000000
#
#                                                     test
# AP (IoU=0.50:0.95, area=all, maxDets=100)       0.630163
# AP (IoU=0.50, area=all, maxDets=100)            0.847076
# AP (IoU=0.75, area=all, maxDets=100)            0.739861
# AP (IoU=0.50:0.95, area=small, maxDets=100)     0.124876
# AP (IoU=0.50:0.95, area=medium, maxDets=100)    0.521251
# AP (IoU=0.50:0.95, area=large, maxDets=100)     0.743253
# AR (IoU=0.50:0.95, area=all, maxDets=1)         0.668258
# AR (IoU=0.50:0.95, area=all, maxDets=10)        0.675367
# AR (IoU=0.50:0.95, area=all, maxDets=100)       0.675367
# AR (IoU=0.50:0.95, area=small, maxDets=100)     0.132828
# AR (IoU=0.50:0.95, area=medium, maxDets=100)    0.562124
# AR (IoU=0.50:0.95, area=large, maxDets=100)     0.794330
# Param                                          41.348181
# FLOPs                                         158.275700
# Time                                           28.200000
# FPS                                            35.400000

# %%
all_metrics.index.name = 'metrics'
all_metrics.to_csv(
    f'results/tables/metrics/baseline/metrics_baseline_{exp_name}.csv', 
    float_format='%.3f')

# %% [markdown]
# # 写入检测结果

# %%
# from src.utils.database import write_detections_2_database
# write_detections_2_database(lib_type='mmdetection', exp_name=exp_name)

# %%
# from src.utils.database import delete_detections_from_database
# delete_detections_from_database(exp_name=exp_name)
