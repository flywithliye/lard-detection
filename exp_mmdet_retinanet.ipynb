# %% [markdown]
# # 训练

# %%
# ./scripts/mmdet_train.sh retinanet

# %%
gpu_id = 0

# %% [markdown]
# # 变量定义

# %%
import glob
import os

# 参数
model_name = 'retinanet'
model_stru = ''
model_cfg = ''
img_size = 1333
exp_name = f'{model_name}{model_stru}{model_cfg}_{img_size}'

# 路径
cfg_path = f'cfg/mmdet/{model_name}_{img_size}.py'
best_model_path = f'runs/mmdetection/{exp_name}/train/'
exp_id = max([f for f in os.listdir(best_model_path) if os.path.isdir(os.path.join(best_model_path, f))])  # 最新实验
files = glob.glob(f'{best_model_path}/best_coco_bbox_mAP_epoch_*.pth')  # TODO: 按epoch数排序
best_model_path = files[0] if files else None
train_log_path = f'runs/mmdetection/{exp_name}/train/{exp_id}/vis_data/scalars.json'

print(f'{exp_name=}')
print(f'{best_model_path=}')
print(f'{train_log_path=}')
# Out:
# exp_name='retinanet_1333'
# best_model_path='runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth'
# train_log_path='runs/mmdetection/retinanet_1333/train/20231213_150310/vis_data/scalars.json'

# %% [markdown]
# # 日志分析

# %%
from src.utils.read import read_mmdet_train_log_json
from src.utils.plot import plot_mmdet_retinanet_train_log

df_train, df_val = read_mmdet_train_log_json(train_log_path)
plot_mmdet_retinanet_train_log(df_train, df_val, exp_name=exp_name)
# Out:
# ['lr', 'data_time', 'loss', 'loss_cls', 'loss_bbox', 'time', 'iter', 'memory', 'step']
# ['coco/bbox_mAP', 'coco/bbox_mAP_50', 'coco/bbox_mAP_75', 'coco/bbox_mAP_s', 'coco/bbox_mAP_m', 'coco/bbox_mAP_l', 'data_time', 'time']
# 最大map: (214)0.922

# %% [markdown]
# # 测试

# %%
! scripts/mmdet_test.sh {cfg_path} {best_model_path} {exp_name} {gpu_id}
# Out:
# 06/02 23:02:14 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:23:11) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu118
#     OpenCV: 4.9.0
#     MMEngine: 0.10.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 0
#     diff_rank_seed: True
#     deterministic: True
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/02 23:02:15 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=True)
# batch_size = dict(test=2, train=2, val=2)
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         122.00711516,
#         141.11828193,
#         164.56574534,
#     ],
#     pad_size_divisor=32,
#     std=[
#         46.91310377,
#         54.8164231,
#         70.38650678,
#     ],
#     type='DetDataPreprocessor')
# data_root = 'datasets/lard/'
# dataset_type = 'LardDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1, max_keep_ckpts=1, save_best='auto', type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.005,
#         monitor='coco/bbox_mAP',
#         patience=50,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=25, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# exp_name = 'retinanet_1333'
# img_size = 1333
# input_size = (
#     1333,
#     800,
# )
# launcher = 'none'
# load_from = 'runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     bbox_head=dict(
#         anchor_generator=dict(
#             octave_base_scale=4,
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales_per_octave=3,
#             strides=[
#                 8,
#                 16,
#                 32,
#                 64,
#                 128,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             alpha=0.25,
#             gamma=2.0,
#             loss_weight=1.0,
#             type='FocalLoss',
#             use_sigmoid=True),
#         num_classes=1,
#         stacked_convs=4,
#         type='RetinaHead'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             122.00711516,
#             141.11828193,
#             164.56574534,
#         ],
#         pad_size_divisor=32,
#         std=[
#             46.91310377,
#             54.8164231,
#             70.38650678,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         add_extra_convs='on_input',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         start_level=1,
#         type='FPN'),
#     test_cfg=dict(
#         max_per_img=8,
#         min_bbox_size=0,
#         nms=dict(iou_threshold=0.6, type='nms'),
#         nms_pre=1000,
#         score_thr=0.001),
#     train_cfg=dict(
#         allowed_border=-1,
#         assigner=dict(
#             ignore_iof_thr=-1,
#             min_pos_iou=0,
#             neg_iou_thr=0.4,
#             pos_iou_thr=0.5,
#             type='MaxIoUAssigner'),
#         debug=False,
#         pos_weight=-1,
#         sampler=dict(type='PseudoSampler')),
#     type='RetinaNet')
# model_cfg = ''
# model_name = 'retinanet'
# model_stru = ''
# num_epochs = 500
# num_workers = 8
# optim_wrapper = dict(
#     optimizer=dict(lr=0.001, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(begin=0, by_epoch=True, end=3, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=3,
#         by_epoch=True,
#         end=500,
#         gamma=0.1,
#         milestones=[
#             350,
#             400,
#         ],
#         type='MultiStepLR'),
# ]
# randomness = dict(deterministic=True, diff_rank_seed=True, seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='annotations/instances_test_synth.json',
#         backend_args=None,
#         data_prefix=dict(img='detection/test_synth/images/'),
#         data_root='datasets/lard/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='LardDataset'),
#     drop_last=False,
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='datasets/lard/annotations/instances_test_synth.json',
#     backend_args=None,
#     format_only=True,
#     metric='bbox',
#     outfile_prefix=
#     'runs/mmdetection/retinanet_1333/test/coco_detection/prediction_test_synth',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         dataset=dict(
#             ann_file='annotations/instances_train.json',
#             backend_args=None,
#             data_prefix=dict(img='detection/train/images/'),
#             data_root='datasets/lard/',
#             filter_cfg=dict(filter_empty_gt=True, min_size=0),
#             pipeline=[
#                 dict(backend_args=None, type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations', with_bbox=True),
#                 dict(keep_ratio=True, scale=(
#                     1333,
#                     800,
#                 ), type='Resize'),
#                 dict(prob=0.5, type='RandomFlip'),
#                 dict(type='PackDetInputs'),
#             ],
#             type='LardDataset'),
#         times=1,
#         type='RepeatDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='annotations/instances_val.json',
#         backend_args=None,
#         data_prefix=dict(img='detection/val/images/'),
#         data_root='datasets/lard/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='LardDataset'),
#     drop_last=False,
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='datasets/lard/annotations/instances_val.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = 'runs/mmdetection/retinanet_1333/test'
#
# 06/02 23:02:16 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/02 23:02:16 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 06/02 23:02:16 - mmengine - WARNING - The prefix is not set in metric class DumpDetResults.
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Loads checkpoint by local backend from path: runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth
# 06/02 23:02:17 - mmengine - INFO - Load checkpoint from runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth
# 06/02 23:02:18 - mmengine - INFO - Epoch(test) [  25/1106]    eta: 0:01:21  time: 0.0751  data_time: 0.0124  memory: 495
# 06/02 23:02:20 - mmengine - INFO - Epoch(test) [  50/1106]    eta: 0:01:06  time: 0.0628  data_time: 0.0079  memory: 495
# 06/02 23:02:21 - mmengine - INFO - Epoch(test) [  75/1106]    eta: 0:01:02  time: 0.0528  data_time: 0.0039  memory: 495
# 06/02 23:02:22 - mmengine - INFO - Epoch(test) [ 100/1106]    eta: 0:00:59  time: 0.0549  data_time: 0.0043  memory: 495
# 06/02 23:02:24 - mmengine - INFO - Epoch(test) [ 125/1106]    eta: 0:00:57  time: 0.0549  data_time: 0.0043  memory: 495
# 06/02 23:02:25 - mmengine - INFO - Epoch(test) [ 150/1106]    eta: 0:00:55  time: 0.0552  data_time: 0.0046  memory: 495
# 06/02 23:02:27 - mmengine - INFO - Epoch(test) [ 175/1106]    eta: 0:00:52  time: 0.0529  data_time: 0.0040  memory: 495
# 06/02 23:02:28 - mmengine - INFO - Epoch(test) [ 200/1106]    eta: 0:00:50  time: 0.0506  data_time: 0.0035  memory: 495
time: 0.0625  data_time: 0.0035  memory: 574
# 06/02 23:07:31 - mmengine - INFO - Epoch(test) [1825/2012]    eta: 0:00:10  time: 0.0624  data_time: 0.0035  memory: 574
# 06/02 23:07:32 - mmengine - INFO - Epoch(test) [1850/2012]    eta: 0:00:09  time: 0.0625  data_time: 0.0035  memory: 574
# 06/02 23:07:34 - mmengine - INFO - Epoch(test) [1875/2012]    eta: 0:00:07  time: 0.0625  data_time: 0.0035  memory: 574
# 06/02 23:07:35 - mmengine - INFO - Epoch(test) [1900/2012]    eta: 0:00:06  time: 0.0626  data_time: 0.0036  memory: 574
# 06/02 23:07:37 - mmengine - INFO - Epoch(test) [1925/2012]    eta: 0:00:04  time: 0.0626  data_time: 0.0036  memory: 574
# 06/02 23:07:39 - mmengine - INFO - Epoch(test) [1950/2012]    eta: 0:00:03  time: 0.0638  data_time: 0.0037  memory: 574
# 06/02 23:07:40 - mmengine - INFO - Epoch(test) [1975/2012]    eta: 0:00:02  time: 0.0648  data_time: 0.0038  memory: 574
# 06/02 23:07:42 - mmengine - INFO - Epoch(test) [2000/2012]    eta: 0:00:00  time: 0.0636  data_time: 0.0037  memory: 574
# 06/02 23:07:43 - mmengine - INFO - results are saved in runs/mmdetection/retinanet_1333/test/coco_detection
# 06/02 23:07:44 - mmengine - INFO - Results has been saved to runs/mmdetection/retinanet_1333/test/coco_detection/prediction_test.pkl.
# 06/02 23:07:44 - mmengine - INFO - Epoch(test) [2012/2012]    data_time: 0.0036  time: 0.0567

# %% [markdown]
# # 评估

# %%
# 提供两种测试评价方案，结果一致
# 方式1: pycocotools
import pandas as pd
from src.utils.metric import coco_metrics_name
from src.utils.metric import cal_coco_metrics

# 保存评价结果对象
coco_evals = {}
# 构造dataframe
all_metrics = {}

# 在各测试集进行推理
for data_type in ['test_synth', 'test_real_nominal', 'test_real_edge', 'test_real', 'test']:

    print(f'正在评价: {data_type}')
    annotation_file = f'datasets/lard/annotations/instances_{data_type}.json'
    prediction_file = f'runs/mmdetection/{exp_name}/test/coco_detection/prediction_{data_type}.bbox.json'
    cocoEval = cal_coco_metrics(annotation_file, prediction_file)
    coco_evals[data_type] = cocoEval
    all_metrics[data_type] = cocoEval.stats

all_metrics = pd.DataFrame(all_metrics, index=coco_metrics_name)
display(all_metrics.round(3))


# 方式2: eval_metric.py
# ! python 3rdparty/mmdetection/tools/analysis_tools/eval_metric.py \
#     {cfg_path} \
#     runs/mmdetection/{exp_name}/test/coco_detection/prediction_test_synth.pkl \
#     --cfg-options \
#     test_evaluator.format_only=False
# Out:
# 正在评价: test_synth
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.08s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.27s).
# Accumulating evaluation results...
# DONE (t=0.33s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.659
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.968
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.767
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.556
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.714
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.738
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.739
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.739
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.632
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
# 正在评价: test_real_nominal
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.16s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.63s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.854
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.678
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.194
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.496
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.789
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.649
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.847
# 正在评价: test_real_edge
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.10s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.435
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.494
# 正在评价: test_real
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.14s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.61s).
# Accumulating evaluation results...
# DONE (t=0.18s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.812
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.618
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.602
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.605
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.605
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.776
# 正在评价: test
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.47s).
# Accumulating evaluation results...
# DONE (t=0.42s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.607
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.897
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.698
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.714
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.677
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.679
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.679
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.787
#                                               test_synth  test_real_nominal  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)          0.659              0.593
# AP (IoU=0.50, area=all, maxDets=100)               0.968              0.854
# AP (IoU=0.75, area=all, maxDets=100)               0.767              0.678
# AP (IoU=0.50:0.95, area=small, maxDets=100)       -1.000              0.194
# AP (IoU=0.50:0.95, area=medium, maxDets=100)       0.556              0.496
# AP (IoU=0.50:0.95, area=large, maxDets=100)        0.714              0.789
# AR (IoU=0.50:0.95, area=all, maxDets=1)            0.738              0.649
# AR (IoU=0.50:0.95, area=all, maxDets=10)           0.739              0.652
# AR (IoU=0.50:0.95, area=all, maxDets=100)          0.739              0.652
# AR (IoU=0.50:0.95, area=small, maxDets=100)       -1.000              0.233
# AR (IoU=0.50:0.95, area=medium, maxDets=100)       0.632              0.552
# AR (IoU=0.50:0.95, area=large, maxDets=100)        0.794              0.847
#
#                                               test_real_edge  test_real   test
# AP (IoU=0.50:0.95, area=all, maxDets=100)              0.331      0.549  0.607
# AP (IoU=0.50, area=all, maxDets=100)                   0.601      0.812  0.897
# AP (IoU=0.75, area=all, maxDets=100)                   0.319      0.618  0.698
# AP (IoU=0.50:0.95, area=small, maxDets=100)            0.111      0.180  0.180
# AP (IoU=0.50:0.95, area=medium, maxDets=100)           0.228      0.456  0.502
# AP (IoU=0.50:0.95, area=large, maxDets=100)            0.435      0.720  0.714
# AR (IoU=0.50:0.95, area=all, maxDets=1)                0.377      0.602  0.677
# AR (IoU=0.50:0.95, area=all, maxDets=10)               0.381      0.605  0.679
# AR (IoU=0.50:0.95, area=all, maxDets=100)              0.381      0.605  0.679
# AR (IoU=0.50:0.95, area=small, maxDets=100)            0.137      0.218  0.218
# AR (IoU=0.50:0.95, area=medium, maxDets=100)           0.267      0.512  0.572
# AR (IoU=0.50:0.95, area=large, maxDets=100)            0.494      0.776  0.787

# %%
# from src.utils.plot import plot_pr_curve

# plot_pr_curve(coco_evals, iou_indices=[0, 2, 4, 6, 8], exp_name=exp_name)

# %% [markdown]
# # 参数量

# %%
# ! scripts/mmdet_flops.sh {cfg_path}

import argparse
import importlib
import pandas as pd
from mmengine.logging import MMLogger
module = importlib.import_module("3rdparty.mmdetection.tools.analysis_tools.get_flops")
inference = module.inference

args = argparse.Namespace(
    config=cfg_path,
    num_images=1,
    cfg_options=dict()
)
logger = MMLogger.get_instance(name='MMLogger')
result = inference(args, logger)
split_line = '=' * 30
ori_shape = result['ori_shape']
pad_shape = result['pad_shape']
flops = result['flops']
params = result['params']
compute_type = result['compute_type']

if pad_shape != ori_shape:
    print(f'{split_line}\nUse size divisor set input shape '
            f'from {ori_shape} to {pad_shape}')
print(f'{split_line}\nCompute type: {compute_type}\n'
        f'Input shape: {pad_shape}\nFlops: {flops}\n'
        f'Params: {params}\n{split_line}')

# 数据重构
all_complex = {}
for data_type in ['test_synth', 'test_real_nominal', 'test_real_edge', 'test_real', 'test']:
    all_complex[data_type] = [params, flops]  # 仅为便于数据拼接
all_complex = pd.DataFrame(
    data=all_complex,
    index=['Param', 'FLOPs']
)

# 合并复杂度指标
all_metrics = pd.concat([all_metrics, all_complex], axis=0)
all_metrics
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 06/02 23:14:15 - mmengine - WARNING - Unsupported operator aten::max_pool2d encountered 1 time(s)
# 06/02 23:14:15 - mmengine - WARNING - Unsupported operator aten::add_ encountered 16 time(s)
# 06/02 23:14:15 - mmengine - WARNING - Unsupported operator aten::add encountered 2 time(s)
# 06/02 23:14:15 - mmengine - WARNING - The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# bbox_head.loss_bbox, bbox_head.loss_cls, bbox_head.relu, data_preprocessor
# 06/02 23:14:15 - mmengine - WARNING - Unsupported operator aten::batch_norm encountered 53 time(s)
# 06/02 23:14:15 - mmengine - WARNING - Unsupported operator aten::upsample_nearest2d encountered 2 time(s)
# ==============================
# Use size divisor set input shape from (2048, 2448) to (800, 960)
# ==============================
# Compute type: dataloader: load a picture from the dataset
# Input shape: (800, 960)
# Flops: 153.05884185600002
# Params: 36.329837
# ==============================
#                                               test_synth  test_real_nominal  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)       0.658579           0.592903
# AP (IoU=0.50, area=all, maxDets=100)            0.967793           0.854186
# AP (IoU=0.75, area=all, maxDets=100)            0.766675           0.677610
# AP (IoU=0.50:0.95, area=small, maxDets=100)    -1.000000           0.193640
# AP (IoU=0.50:0.95, area=medium, maxDets=100)    0.555812           0.495559
# AP (IoU=0.50:0.95, area=large, maxDets=100)     0.713521           0.788587
# AR (IoU=0.50:0.95, area=all, maxDets=1)         0.738427           0.648600
# AR (IoU=0.50:0.95, area=all, maxDets=10)        0.739195           0.651533
# AR (IoU=0.50:0.95, area=all, maxDets=100)       0.739195           0.651533
# AR (IoU=0.50:0.95, area=small, maxDets=100)    -1.000000           0.232738
# AR (IoU=0.50:0.95, area=medium, maxDets=100)    0.631903           0.552174
# AR (IoU=0.50:0.95, area=large, maxDets=100)     0.793793           0.846802
# Param                                          36.329837          36.329837
# FLOPs                                         153.058842         153.058842
#
#                                               test_real_edge   test_real  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)           0.330716    0.549406
# AP (IoU=0.50, area=all, maxDets=100)                0.600502    0.812049
# AP (IoU=0.75, area=all, maxDets=100)                0.318790    0.618034
# AP (IoU=0.50:0.95, area=small, maxDets=100)         0.111038    0.179752
# AP (IoU=0.50:0.95, area=medium, maxDets=100)        0.227819    0.456039
# AP (IoU=0.50:0.95, area=large, maxDets=100)         0.435110    0.720493
# AR (IoU=0.50:0.95, area=all, maxDets=1)             0.377170    0.601988
# AR (IoU=0.50:0.95, area=all, maxDets=10)            0.381350    0.605135
# AR (IoU=0.50:0.95, area=all, maxDets=100)           0.381350    0.605135
# AR (IoU=0.50:0.95, area=small, maxDets=100)         0.136667    0.218182
# AR (IoU=0.50:0.95, area=medium, maxDets=100)        0.267290    0.511585
# AR (IoU=0.50:0.95, area=large, maxDets=100)         0.493678    0.775522
# Param                                              36.329837   36.329837
# FLOPs                                             153.058842  153.058842
#
#                                                     test
# AP (IoU=0.50:0.95, area=all, maxDets=100)       0.606962
# AP (IoU=0.50, area=all, maxDets=100)            0.896770
# AP (IoU=0.75, area=all, maxDets=100)            0.697639
# AP (IoU=0.50:0.95, area=small, maxDets=100)     0.179726
# AP (IoU=0.50:0.95, area=medium, maxDets=100)    0.501644
# AP (IoU=0.50:0.95, area=large, maxDets=100)     0.713975
# AR (IoU=0.50:0.95, area=all, maxDets=1)         0.677231
# AR (IoU=0.50:0.95, area=all, maxDets=10)        0.679070
# AR (IoU=0.50:0.95, area=all, maxDets=100)       0.679070
# AR (IoU=0.50:0.95, area=small, maxDets=100)     0.218182
# AR (IoU=0.50:0.95, area=medium, maxDets=100)    0.571543
# AR (IoU=0.50:0.95, area=large, maxDets=100)     0.787414
# Param                                          36.329837
# FLOPs                                         153.058842

# %% [markdown]
# # 测速

# %%
! scripts/mmdet_speed.sh {cfg_path} {best_model_path} {gpu_id}
# Out:
# 06/02 23:14:42 - mmengine - INFO - before build:
# 06/02 23:14:42 - mmengine - INFO - (GB) mem_used: 5.31 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 06/02 23:14:43 - mmengine - INFO - after build:
# 06/02 23:14:43 - mmengine - INFO - (GB) mem_used: 5.63 | uss: 0.62 | pss: 0.74 | total_proc: 1
# 06/02 23:15:20 - mmengine - INFO - ==================================
# 06/02 23:15:20 - mmengine - INFO - Done image [500/2000], fps: 38.2 img/s, times per image: 26.2 ms/img, cuda memory: 373 MB
# 06/02 23:15:20 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:15:56 - mmengine - INFO - ==================================
# 06/02 23:15:56 - mmengine - INFO - Done image [1000/2000], fps: 38.2 img/s, times per image: 26.2 ms/img, cuda memory: 373 MB
# 06/02 23:15:56 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:16:32 - mmengine - INFO - ==================================
# 06/02 23:16:32 - mmengine - INFO - Done image [1500/2000], fps: 38.2 img/s, times per image: 26.2 ms/img, cuda memory: 373 MB
# 06/02 23:16:32 - mmengine - INFO - (GB) mem_used: 5.82 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:17:08 - mmengine - INFO - ==================================
# 06/02 23:17:08 - mmengine - INFO - Done image [2000/2000], fps: 38.2 img/s, times per image: 26.2 ms/img, cuda memory: 373 MB
# 06/02 23:17:08 - mmengine - INFO - (GB) mem_used: 5.82 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:17:08 - mmengine - INFO - ============== Done ==================
# 06/02 23:17:08 - mmengine - INFO - Overall fps: 38.2 img/s, times per image: 26.2 ms/img
# 06/02 23:17:08 - mmengine - INFO - cuda memory: 141 MB
# 06/02 23:17:08 - mmengine - INFO - (GB) mem_used: 5.82 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:17:11 - mmengine - INFO - before build:
# 06/02 23:17:11 - mmengine - INFO - (GB) mem_used: 5.32 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/02 23:17:12 - mmengine - INFO - after build:
# 06/02 23:17:12 - mmengine - INFO - (GB) mem_used: 5.64 | uss: 0.62 | pss: 0.74 | total_proc: 1
# 06/02 23:18:07 - mmengine - INFO - ==================================
# 06/02 23:18:07 - mmengine - INFO - Done image [500/2000], fps: 32.4 img/s, times per image: 30.8 ms/img, cuda memory: 423 MB
# 06/02 23:18:07 - mmengine - INFO - (GB) mem_used: 5.80 | uss: 0.82 | pss: 0.98 | total_proc: 1
# 06/02 23:19:02 - mmengine - INFO - ==================================
# 06/02 23:19:02 - mmengine - INFO - Done image [1000/2000], fps: 32.4 img/s, times per image: 30.9 ms/img, cuda memory: 422 MB
# 06/02 23:19:02 - mmengine - INFO - (GB) mem_used: 5.80 | uss: 0.82 | pss: 0.98 | total_proc: 1
# 06/02 23:19:55 - mmengine - INFO - ==================================
# 06/02 23:19:55 - mmengine - INFO - Done image [1500/2000], fps: 32.5 img/s, times per image: 30.8 ms/img, cuda memory: 422 MB
# 06/02 23:19:55 - mmengine - INFO - (GB) mem_used: 5.79 | uss: 0.81 | pss: 0.97 | total_proc: 1
# 06/02 23:19:55 - mmengine - INFO - ============== Done ==================
# 06/02 23:19:55 - mmengine - INFO - Overall fps: 32.5 img/s, times per image: 30.8 ms/img
# 06/02 23:19:55 - mmengine - INFO - cuda memory: 141 MB
# 06/02 23:19:55 - mmengine - INFO - (GB) mem_used: 5.79 | uss: 0.81 | pss: 0.97 | total_proc: 1
# 06/02 23:19:58 - mmengine - INFO - before build:
# 06/02 23:19:59 - mmengine - INFO - (GB) mem_used: 5.31 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/02 23:20:00 - mmengine - INFO - after build:
# 06/02 23:20:00 - mmengine - INFO - (GB) mem_used: 5.63 | uss: 0.62 | pss: 0.73 | total_proc: 1
# 06/02 23:20:11 - mmengine - INFO - ==================================
# 06/02 23:20:22 - mmengine - INFO - ==================================
# 06/02 23:20:22 - mmengine - INFO - Done image [200/2000], fps: 32.8 img/s, times per image: 30.5 ms/img, cuda memory: 423 MB
# 06/02 23:20:22 - mmengine - INFO - (GB) mem_used: 5.79 | uss: 0.82 | pss: 0.98 | total_proc: 1
# 06/02 23:20:32 - mmengine - INFO - ==================================
# 06/02 23:20:32 - mmengine - INFO - Done image [300/2000], fps: 32.5 img/s, times per image: 30.8 ms/img, cuda memory: 422 MB
# 06/02 23:20:33 - mmengine - INFO - (GB) mem_used: 5.79 | uss: 0.82 | pss: 0.98 | total_proc: 1
# 06/02 23:20:34 - mmengine - INFO - ============== Done ==================
# 06/02 23:20:34 - mmengine - INFO - Overall fps: 32.5 img/s, times per image: 30.8 ms/img
# 06/02 23:20:34 - mmengine - INFO - cuda memory: 422 MB
# 06/02 23:20:34 - mmengine - INFO - (GB) mem_used: 5.79 | uss: 0.82 | pss: 0.98 | total_proc: 1
# 06/02 23:20:37 - mmengine - INFO - before build:
# 06/02 23:20:37 - mmengine - INFO - (GB) mem_used: 5.30 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/02 23:20:38 - mmengine - INFO - after build:
# 06/02 23:20:38 - mmengine - INFO - (GB) mem_used: 5.62 | uss: 0.62 | pss: 0.74 | total_proc: 1
# 06/02 23:21:33 - mmengine - INFO - ==================================
# 06/02 23:21:33 - mmengine - INFO - Done image [500/2000], fps: 32.4 img/s, times per image: 30.9 ms/img, cuda memory: 423 MB
# 06/02 23:21:33 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:22:28 - mmengine - INFO - ==================================
# 06/02 23:22:28 - mmengine - INFO - Done image [1000/2000], fps: 32.4 img/s, times per image: 30.9 ms/img, cuda memory: 422 MB
# 06/02 23:22:28 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:23:21 - mmengine - INFO - ==================================
# 06/02 23:23:21 - mmengine - INFO - Done image [1500/2000], fps: 32.4 img/s, times per image: 30.8 ms/img, cuda memory: 422 MB
# 06/02 23:23:21 - mmengine - INFO - (GB) mem_used: 5.80 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:23:54 - mmengine - INFO - ============== Done ==================
# 06/02 23:23:54 - mmengine - INFO - Overall fps: 32.4 img/s, times per image: 30.9 ms/img
# 06/02 23:23:54 - mmengine - INFO - cuda memory: 422 MB
# 06/02 23:23:55 - mmengine - INFO - (GB) mem_used: 5.80 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:23:58 - mmengine - INFO - before build:
# 06/02 23:23:58 - mmengine - INFO - (GB) mem_used: 5.31 | uss: 0.29 | pss: 0.40 | total_proc: 1
# Loads checkpoint by local backend from path: runs/mmdetection/retinanet_1333/train/best_coco_bbox_mAP_epoch_214.pth
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 06/02 23:23:59 - mmengine - INFO - after build:
# 06/02 23:23:59 - mmengine - INFO - (GB) mem_used: 5.63 | uss: 0.62 | pss: 0.74 | total_proc: 1
# 06/02 23:24:35 - mmengine - INFO - ==================================
# 06/02 23:24:35 - mmengine - INFO - Done image [500/2000], fps: 38.3 img/s, times per image: 26.1 ms/img, cuda memory: 373 MB
# 06/02 23:24:35 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:25:11 - mmengine - INFO - ==================================
# 06/02 23:25:11 - mmengine - INFO - Done image [1000/2000], fps: 38.4 img/s, times per image: 26.0 ms/img, cuda memory: 373 MB
# 06/02 23:25:11 - mmengine - INFO - (GB) mem_used: 5.80 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:25:46 - mmengine - INFO - ==================================
# 06/02 23:25:46 - mmengine - INFO - Done image [1500/2000], fps: 38.4 img/s, times per image: 26.0 ms/img, cuda memory: 373 MB
# 06/02 23:25:46 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:26:22 - mmengine - INFO - ==================================
# 06/02 23:26:22 - mmengine - INFO - Done image [2000/2000], fps: 38.4 img/s, times per image: 26.0 ms/img, cuda memory: 373 MB
# 06/02 23:26:22 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.83 | pss: 0.99 | total_proc: 1
# 06/02 23:26:22 - mmengine - INFO - ============== Done ==================
# 06/02 23:26:22 - mmengine - INFO - Overall fps: 38.4 img/s, times per image: 26.0 ms/img
# 06/02 23:26:22 - mmengine - INFO - cuda memory: 141 MB
# 06/02 23:26:22 - mmengine - INFO - (GB) mem_used: 5.81 | uss: 0.83 | pss: 0.99 | total_proc: 1

# %%
# 06/02 23:17:08 - mmengine - INFO - ============== Done ==================
# 06/02 23:17:08 - mmengine - INFO - Overall fps: 38.2 img/s, times per image: 26.2 ms/img

# 06/02 23:19:55 - mmengine - INFO - ============== Done ==================
# 06/02 23:19:55 - mmengine - INFO - Overall fps: 32.5 img/s, times per image: 30.8 ms/img

# 06/02 23:20:34 - mmengine - INFO - ============== Done ==================
# 06/02 23:20:34 - mmengine - INFO - Overall fps: 32.5 img/s, times per image: 30.8 ms/img

# 06/02 23:23:54 - mmengine - INFO - ============== Done ==================
# 06/02 23:23:54 - mmengine - INFO - Overall fps: 32.4 img/s, times per image: 30.9 ms/img

# 06/02 23:26:22 - mmengine - INFO - ============== Done ==================
# 06/02 23:26:22 - mmengine - INFO - Overall fps: 38.4 img/s, times per image: 26.0 ms/img

# %%
# 保存结果
all_speed = {
    'test_synth': [26.2, 38.2],  # [average_time, fps]
    'test_real_nominal': [30.8, 32.5],
    'test_real_edge': [30.8, 32.5],
    'test_real': [30.9, 32.4],
    'test': [26.0, 38.4]
}

# 构建dataframe
all_speed = pd.DataFrame(
    data=all_speed,
    index=['Time', 'FPS']
)

# 合并测试指标
all_metrics = pd.concat([all_metrics, all_speed], axis=0)
all_metrics
# Out:
#                                               test_synth  test_real_nominal  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)       0.658579           0.592903
# AP (IoU=0.50, area=all, maxDets=100)            0.967793           0.854186
# AP (IoU=0.75, area=all, maxDets=100)            0.766675           0.677610
# AP (IoU=0.50:0.95, area=small, maxDets=100)    -1.000000           0.193640
# AP (IoU=0.50:0.95, area=medium, maxDets=100)    0.555812           0.495559
# AP (IoU=0.50:0.95, area=large, maxDets=100)     0.713521           0.788587
# AR (IoU=0.50:0.95, area=all, maxDets=1)         0.738427           0.648600
# AR (IoU=0.50:0.95, area=all, maxDets=10)        0.739195           0.651533
# AR (IoU=0.50:0.95, area=all, maxDets=100)       0.739195           0.651533
# AR (IoU=0.50:0.95, area=small, maxDets=100)    -1.000000           0.232738
# AR (IoU=0.50:0.95, area=medium, maxDets=100)    0.631903           0.552174
# AR (IoU=0.50:0.95, area=large, maxDets=100)     0.793793           0.846802
# Param                                          36.329837          36.329837
# FLOPs                                         153.058842         153.058842
# Time                                           26.200000          30.800000
# FPS                                            38.200000          32.500000
#
#                                               test_real_edge   test_real  \
# AP (IoU=0.50:0.95, area=all, maxDets=100)           0.330716    0.549406
# AP (IoU=0.50, area=all, maxDets=100)                0.600502    0.812049
# AP (IoU=0.75, area=all, maxDets=100)                0.318790    0.618034
# AP (IoU=0.50:0.95, area=small, maxDets=100)         0.111038    0.179752
# AP (IoU=0.50:0.95, area=medium, maxDets=100)        0.227819    0.456039
# AP (IoU=0.50:0.95, area=large, maxDets=100)         0.435110    0.720493
# AR (IoU=0.50:0.95, area=all, maxDets=1)             0.377170    0.601988
# AR (IoU=0.50:0.95, area=all, maxDets=10)            0.381350    0.605135
# AR (IoU=0.50:0.95, area=all, maxDets=100)           0.381350    0.605135
# AR (IoU=0.50:0.95, area=small, maxDets=100)         0.136667    0.218182
# AR (IoU=0.50:0.95, area=medium, maxDets=100)        0.267290    0.511585
# AR (IoU=0.50:0.95, area=large, maxDets=100)         0.493678    0.775522
# Param                                              36.329837   36.329837
# FLOPs                                             153.058842  153.058842
# Time                                               30.800000   30.900000
# FPS                                                32.500000   32.400000
#
#                                                     test
# AP (IoU=0.50:0.95, area=all, maxDets=100)       0.606962
# AP (IoU=0.50, area=all, maxDets=100)            0.896770
# AP (IoU=0.75, area=all, maxDets=100)            0.697639
# AP (IoU=0.50:0.95, area=small, maxDets=100)     0.179726
# AP (IoU=0.50:0.95, area=medium, maxDets=100)    0.501644
# AP (IoU=0.50:0.95, area=large, maxDets=100)     0.713975
# AR (IoU=0.50:0.95, area=all, maxDets=1)         0.677231
# AR (IoU=0.50:0.95, area=all, maxDets=10)        0.679070
# AR (IoU=0.50:0.95, area=all, maxDets=100)       0.679070
# AR (IoU=0.50:0.95, area=small, maxDets=100)     0.218182
# AR (IoU=0.50:0.95, area=medium, maxDets=100)    0.571543
# AR (IoU=0.50:0.95, area=large, maxDets=100)     0.787414
# Param                                          36.329837
# FLOPs                                         153.058842
# Time                                           26.000000
# FPS                                            38.400000

# %%
all_metrics.index.name = 'metrics'
all_metrics.to_csv(
    f'results/tables/metrics/baseline/metrics_baseline_{exp_name}.csv', 
    float_format='%.3f')

# %% [markdown]
# # 写入检测结果

# %%
# from src.utils.database import write_detections_2_database
# write_detections_2_database(lib_type='mmdetection', exp_name=exp_name)

# %%
# from src.utils.database import delete_detections_from_database
# delete_detections_from_database(exp_name=exp_name)
